# %%
# !sudo apt install tensorrt
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cuda-cccl-12-1 cuda-cudart-12-1 cuda-cudart-dev-12-1 cuda-driver-dev-12-1
#   cuda-nvcc-12-1 cuda-toolkit-12-1-config-common libnvinfer-bin libnvinfer-dev
#   libnvinfer-dispatch-dev libnvinfer-dispatch8 libnvinfer-headers-dev
#   libnvinfer-headers-plugin-dev libnvinfer-lean-dev libnvinfer-lean8
#   libnvinfer-plugin-dev libnvinfer-plugin8 libnvinfer-samples
#   libnvinfer-vc-plugin-dev libnvinfer-vc-plugin8 libnvinfer8
#   libnvonnxparsers-dev libnvonnxparsers8 libnvparsers-dev libnvparsers8
# The following NEW packages will be installed:
#   cuda-cccl-12-1 cuda-cudart-12-1 cuda-cudart-dev-12-1 cuda-driver-dev-12-1
#   cuda-nvcc-12-1 cuda-toolkit-12-1-config-common libnvinfer-bin libnvinfer-dev
#   libnvinfer-dispatch-dev libnvinfer-dispatch8 libnvinfer-headers-dev
# ...

# %%
# !/usr/src/tensorrt/bin/trtexec --fp16 --onnx="/content/model_A100.onnx" --saveEngine="/content/model_A100.engine"
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8601] # /usr/src/tensorrt/bin/trtexec --fp16 --onnx=/content/model_A100.onnx --saveEngine=/content/model_A100.engine
# [03/06/2024-11:46:44] [I] === Model Options ===
# [03/06/2024-11:46:44] [I] Format: ONNX
# [03/06/2024-11:46:44] [I] Model: /content/model_A100.onnx
# [03/06/2024-11:46:44] [I] Output:
# [03/06/2024-11:46:44] [I] === Build Options ===
# [03/06/2024-11:46:44] [I] Max batch: explicit batch
# [03/06/2024-11:46:44] [I] Memory Pools: workspace: default, dlaSRAM: default, dlaLocalDRAM: default, dlaGlobalDRAM: default
# [03/06/2024-11:46:44] [I] minTiming: 1
# [03/06/2024-11:46:44] [I] avgTiming: 8
# [03/06/2024-11:46:44] [I] Precision: FP32+FP16
# [03/06/2024-11:46:44] [I] LayerPrecisions:
# [03/06/2024-11:46:44] [I] Layer Device Types:
# [03/06/2024-11:46:44] [I] Calibration:
# [03/06/2024-11:46:44] [I] Refit: Disabled
# [03/06/2024-11:46:44] [I] Version Compatible: Disabled
# [03/06/2024-11:46:44] [I] TensorRT runtime: full
# ...
