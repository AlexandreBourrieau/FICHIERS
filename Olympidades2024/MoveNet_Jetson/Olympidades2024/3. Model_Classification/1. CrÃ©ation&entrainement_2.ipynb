# %% [markdown]
# # Entrainement du modèle
#
# Dans ce notebook, nous allons entrainer notre modèle afin qu'il puisse classifier les positions capturées avec la caméra dans les classes ``correct`` ou ``non correcte``. Le modèle que nous allons utiliser est dérivé du modèle MoveNet.
#
# Nous allons utiliser la librairie Keras / Tensorflow pour créer notre modèle.

# %%
import tensorflow as tf
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm

from tensorflow import keras
from matplotlib import pyplot as plt

# %% [markdown]
# ### Téléchargement et extraction des données collectées
#
# Tout d'abord il faut récupérer les données collectées contenues dans le fichier ``dataset.zip`` que nous avons créé précedemment. Pour cela, il suffit d'exécuter la commande ci-dessous.

# %%
#!unzip -q dataset.zip

# %% [markdown]
# Un dossier nommé ``dataset`` devrait apparaître dans l'explorateur de fichiers.

# %% [markdown]
# # Création des datasets

# %% [markdown]
# ### Chargement des images dans le dataset d'entrainement

# %% [markdown]
# A partir des images sauvegardées dans le répertoire de travail, on peut maintenant créer notre dataset. On commence par créer une liste contenant les deux classes utilisées :

# %%
nom_position = "Corbeau"

CATEGORIES = ['correct', 'non_correct']
datasets = {}
for name in CATEGORIES:
    datasets[name] = []

# %% [markdown]
# On charge ensuite les données à l'aide de la fonction ``image_dataset_from_directory`` de Keras, en précisant la résolution des images et le type de label associé (ici on utilise le type ``categorical`` - voir ci-dessous). On demande également d'utiliser un ``batch size`` de 1 et d'utiliser 90% des images pour l'entrainement et les 10% restant pour les validations :

# %%
# Récupère le répertoire courant
repertoire_courant = os.getcwd()

# Création du dataset d'entrainement
dataset_entrainement = tf.keras.preprocessing.image_dataset_from_directory(
    repertoire_courant + "/dataset/" + nom_position + "/",
    validation_split=0.2,
    subset="training",
    image_size=(256, 256),
    batch_size=1,
    shuffle=True,
    seed=123,
    label_mode='categorical')

# Création du dataset de validation
dataset_validation = tf.keras.preprocessing.image_dataset_from_directory(
    repertoire_courant + "/dataset/" + nom_position + "/",
    validation_split=0.2,
    subset="validation",
    image_size=(256, 256),
    batch_size=1,
    shuffle=True,
    seed=123,
    label_mode='categorical')
# Out:
# Found 61 files belonging to 2 classes.
# Using 49 files for training.
# Found 61 files belonging to 2 classes.
# Using 12 files for validation.

# %%
# Extraciton des tenseurs depuis le dataset
images_entrainement, labels_entrainement = tuple(zip(*dataset_entrainement))
images_validation, labels_validation = tuple(zip(*dataset_validation))

# %% [markdown]
# Observons le nom des classes utilisées :

# %%
class_names = dataset_entrainement.class_names
print(class_names)
# Out:
# ['CORRECT', 'NON_CORRECT']

# %% [markdown]
# Regardons le format du tenseur contenu dans le dataset :

# %%
for image,label in dataset_entrainement.take(2):
    print(image.shape)
    print(label.shape)
# Out:
# (1, 256, 256, 3)
# (1, 2)
# (1, 256, 256, 3)
# (1, 2)

# %% [markdown]
# Affichons quelques labels codé de manière "categorical" et leur valeur équivalente "binaire" :

# %%
for image,label in dataset_entrainement.take(5):
    print("Label categorical : %s" %label[0])
    print("Label binaire correspondant : %s" %np.argmax(label[0], axis=None, out=None))
    print("Classe correspondante : %s" %class_names[np.argmax(label[0], axis=None, out=None)])
    print("")
# Out:
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT
#
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT
#
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT
#
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT
#
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT

# %% [markdown]
# Affichons maintenant quelques images :

# %%
plt.figure(figsize=(10, 10))

for i in range(8):
    index = np.random.randint(0,len(dataset_entrainement))
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images_entrainement[index][0].numpy().astype("uint8"))
    plt.title(class_names[np.argmax(labels_entrainement[index][0], axis=None, out=None)])
    plt.axis("off")

# %% [markdown]
# On va maintenant utiliser le modèle MoveNet pour créer les données d'entrées pour l'entrainement

# %%
import tensorrt as trt
import pycuda.driver as cuda
import pycuda.autoinit

PRECISION = trt.int32

# Construction de la class du logger
class MyLogger(trt.ILogger):
    def __init__(self):
        trt.ILogger.__init__(self)

    def log(self, severity, msg):
        print("%s : %s" %(severity,msg))
        pass

logger = MyLogger()
runtime = trt.Runtime(logger)

with open("model_jetson.engine", "rb") as f:
    engine = runtime.deserialize_cuda_engine(f.read())

context = engine.create_execution_context()

# Réservation de la mémoire pour l'entrée
size_input = trt.volume(engine.get_binding_shape(0))* engine.max_batch_size
input_host_mem = cuda.pagelocked_empty(size_input, trt.nptype(PRECISION))
input_device_mem = cuda.mem_alloc(input_host_mem.nbytes)

# Réservation de la mémoire pour les sorties
output_device_mem = [];
format_sorties = [];
types_sorties = [];

for i in range(engine.num_bindings):
    if not engine.binding_is_input(i):
        size_output = trt.volume(engine.get_binding_shape(i))* engine.max_batch_size
        output_host_mem = cuda.pagelocked_empty(size_output, trt.nptype(PRECISION))
        output_device_mem.append(cuda.mem_alloc(output_host_mem.nbytes))
        format_sorties.append(engine.get_binding_shape(i))
        types_sorties.append(trt.nptype(engine.get_binding_dtype(i)))

# Récupère les adresses en GPU des buffers entrées / sorties
binding_entree = int(input_device_mem)

binding_sorties = []
for output_ in output_device_mem:
    binding_sorties.append(int(output_))

# Initialise le moteur
print("Initialisation du moteur..")
x = images_entrainement[0].numpy().astype(np.int32)
np.copyto(input_host_mem,x.ravel())
cuda.memcpy_htod(input_device_mem, input_host_mem)
bindings = [binding_entree, binding_sorties[0]]
context.execute_v2(bindings=bindings)
# Out:
# Severity.INFO : [MemUsageChange] Init CUDA: CPU +224, GPU +1, now: CPU 878, GPU 3456 (MiB)
# Severity.INFO : Loaded engine size: 16 MiB
# Severity.WARNING : Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# Severity.VERBOSE : Using cublas as a tactic source
# Severity.INFO : [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +158, GPU +8, now: CPU 1055, GPU 3461 (MiB)
# Severity.VERBOSE : Using cuDNN as a tactic source
# Severity.INFO : [MemUsageChange] Init cuDNN: CPU +241, GPU -9, now: CPU 1296, GPU 3452 (MiB)
# Severity.VERBOSE : Deserialization required 13718782 microseconds.
# Severity.INFO : [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +14, now: CPU 0, GPU 14 (MiB)
# Severity.VERBOSE : Using cublas as a tactic source
# Severity.INFO : [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 1279, GPU 3445 (MiB)
# Severity.VERBOSE : Using cuDNN as a tactic source
# Severity.INFO : [MemUsageChange] Init cuDNN: CPU +0, GPU +1, now: CPU 1279, GPU 3446 (MiB)
# Severity.VERBOSE : Total per-runner device persistent memory is 13678592
# Severity.VERBOSE : Total per-runner host persistent memory is 157056
# Severity.VERBOSE : Allocated activation device memory of size 18387456
# Severity.INFO : [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +30, now: CPU 0, GPU 44 (MiB)
# Initialisation du moteur..
# True

# %%
predictions_entrainement = []
predictions_validation = []

for i in tqdm(range(len(dataset_entrainement))):
    x = images_entrainement[i].numpy().astype(np.int32)
    np.copyto(input_host_mem,x.ravel())
    cuda.memcpy_htod(input_device_mem, input_host_mem)
    bindings = [binding_entree, binding_sorties[0]]
    context.execute_v2(bindings=bindings)
    output_host_mem = np.zeros(format_sorties[0],types_sorties[0])
    cuda.memcpy_dtoh(output_host_mem[0], output_device_mem[0])
    predictions_entrainement.append(output_host_mem[0][0])

for i in tqdm(range(len(dataset_validation))):
    x = images_validation[i].numpy().astype(np.int32)
    np.copyto(input_host_mem,x.ravel())
    cuda.memcpy_htod(input_device_mem, input_host_mem)
    bindings = [binding_entree, binding_sorties[0]]
    context.execute_v2(bindings=bindings)
    output_host_mem = np.zeros(format_sorties[0],types_sorties[0])
    cuda.memcpy_dtoh(output_host_mem[0], output_device_mem[0])
    predictions_validation.append(output_host_mem[0][0])
# Out:
# 100%|██████████| 49/49 [00:02<00:00, 19.44it/s]
# 100%|██████████| 12/12 [00:00<00:00, 25.19it/s]

# %% [markdown]
# # Vérification des positions

# %%
import cv2

def draw_lines(img_cv2, coordonneesXY, line_width=1):
    width, height = (256,256)

    nez = [int(coordonneesXY[0][1]*width),int(coordonneesXY[0][0]*height)]
    oeuil_gauche = [int(coordonneesXY[1][1]*width),int(coordonneesXY[1][0]*height)]
    oeuil_droit = [int(coordonneesXY[2][1]*width),int(coordonneesXY[2][0]*height)]
    oreille_gauche = [int(coordonneesXY[3][1]*width),int(coordonneesXY[3][0]*height)]
    oreille_droite = [int(coordonneesXY[4][1]*width),int(coordonneesXY[4][0]*height)]
    epaule_gauche = [int(coordonneesXY[5][1]*width),int(coordonneesXY[5][0]*height)]
    epaule_droite = [int(coordonneesXY[6][1]*width),int(coordonneesXY[6][0]*height)]
    coude_gauche = [int(coordonneesXY[7][1]*width),int(coordonneesXY[7][0]*height)]
    coude_droite = [int(coordonneesXY[8][1]*width),int(coordonneesXY[8][0]*height)]
    poignet_gauche = [int(coordonneesXY[9][1]*width),int(coordonneesXY[9][0]*height)]
    poignet_droite = [int(coordonneesXY[10][1]*width),int(coordonneesXY[10][0]*height)]
    hanche_gauche = [int(coordonneesXY[11][1]*width),int(coordonneesXY[11][0]*height)]
    hanche_droite = [int(coordonneesXY[12][1]*width),int(coordonneesXY[12][0]*height)]
    genou_gauche = [int(coordonneesXY[13][1]*width),int(coordonneesXY[13][0]*height)]
    genou_droite = [int(coordonneesXY[14][1]*width),int(coordonneesXY[14][0]*height)]
    cheville_gauche = [int(coordonneesXY[15][1]*width),int(coordonneesXY[15][0]*height)]
    cheville_droite = [int(coordonneesXY[16][1]*width),int(coordonneesXY[16][0]*height)]


    centre_yeux = [((int(0.5*(coordonneesXY[1][1]*width+int(coordonneesXY[2][1]*width))))),((int(0.5*(coordonneesXY[1][0]*height+int(coordonneesXY[2][0]*height)))))]
    centre_epaules = [((int(0.5*(coordonneesXY[5][1]*width+int(coordonneesXY[6][1]*width))))),((int(0.5*(coordonneesXY[5][0]*height+int(coordonneesXY[6][0]*height)))))]
    centre_hanches =  [((int(0.5*(coordonneesXY[11][1]*width+int(coordonneesXY[12][1]*width))))),((int(0.5*(coordonneesXY[11][0]*height+int(coordonneesXY[12][0]*height)))))]


    # Lignes nez-centre des yeux
    img = cv2.line(img_cv2, (nez[0],nez[1]),(centre_yeux[0],centre_yeux[1]),color=(0, 0, 255), thickness=2)

    # Lignes centre des yeux - oueil gauche
    img = cv2.line(img_cv2, (oeuil_gauche[0],oeuil_gauche[1]),(centre_yeux[0],centre_yeux[1]),color=(0, 0, 255), thickness=2)

    # Lignes centre des yeux - oueil droit
    img = cv2.line(img_cv2, (oeuil_droit[0],oeuil_droit[1]),(centre_yeux[0],centre_yeux[1]),color=(0, 0, 255), thickness=2)

    # Lignes oeuil_gauche - oreille gauche
    img = cv2.line(img_cv2, (oeuil_gauche[0],oeuil_gauche[1]),(oreille_gauche[0],oreille_gauche[1]),color=(0, 0, 255), thickness=2)

    # Lignes oeuil_droit - oreille droite
    img = cv2.line(img_cv2, (oeuil_droit[0],oeuil_droit[1]),(oreille_droite[0],oreille_droite[1]),color=(0, 0, 255), thickness=2)

    # Lignes nez-centre_epaules
    img = cv2.line(img_cv2, (nez[0],nez[1]),(centre_epaules[0],centre_epaules[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_epaules - epaule_droit
    img = cv2.line(img_cv2, (epaule_droite[0],epaule_droite[1]),(centre_epaules[0],centre_epaules[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_epaules - epaule_gauche
    img = cv2.line(img_cv2, (epaule_gauche[0],epaule_gauche[1]),(centre_epaules[0],centre_epaules[1]),color=(0, 0, 255), thickness=2)

    # Ligne épaule_gauche - coude_gouche
    img = cv2.line(img_cv2, (epaule_gauche[0],epaule_gauche[1]),(coude_gauche[0],coude_gauche[1]),color=(0, 0, 255), thickness=2)

    # Ligne coude_gouche - poignet_gauche
    img = cv2.line(img_cv2, (poignet_gauche[0],poignet_gauche[1]),(coude_gauche[0],coude_gauche[1]),color=(0, 0, 255), thickness=2)

    # Ligne épaule_droite - coude_doit
    img = cv2.line(img_cv2, (epaule_droite[0],epaule_droite[1]),(coude_droite[0],coude_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne coude_droite - poignet_droite
    img = cv2.line(img_cv2, (poignet_droite[0],poignet_droite[1]),(coude_droite[0],coude_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_epaules - centre_hanche
    img = cv2.line(img_cv2, (centre_hanches[0],centre_hanches[1]),(centre_epaules[0],centre_epaules[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_hanche - hanche_gauche
    img = cv2.line(img_cv2, (centre_hanches[0],centre_hanches[1]),(hanche_gauche[0],hanche_gauche[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_hanche - hanche_gauche
    img = cv2.line(img_cv2, (centre_hanches[0],centre_hanches[1]),(hanche_droite[0],hanche_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne hanche_gauche - genou_gauche
    img = cv2.line(img_cv2, (genou_gauche[0],genou_gauche[1]),(hanche_gauche[0],hanche_gauche[1]),color=(0, 0, 255), thickness=2)

    # Ligne hanche_droite - genou_droite
    img = cv2.line(img_cv2, (genou_droite[0],genou_droite[1]),(hanche_droite[0],hanche_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne genou_droite - cheville_droite
    img = cv2.line(img_cv2, (genou_droite[0],genou_droite[1]),(cheville_droite[0],cheville_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne genou_gauche - cheville_gauche
    img = cv2.line(img_cv2, (genou_gauche[0],genou_gauche[1]),(cheville_gauche[0],cheville_gauche[1]),color=(0, 0, 255), thickness=2)

    return img

# %%
plt.figure(figsize=(10, 10))

for i in range(8):
    ax = plt.subplot(4, 4, i + 1)
    index = np.random.randint(0,len(dataset_entrainement))
    image = keras.utils.array_to_img(images_entrainement[index][0])
    image = np.array(image)
    draw_image = draw_lines(image, predictions_entrainement[index])
    plt.imshow(draw_image.astype("uint8"))
    plt.title(class_names[np.argmax(labels_entrainement[index], axis=None, out=None)])
    plt.axis("off")

# %% [markdown]
# # Création du modèle

# %% [markdown]
# Le modèle que nous allons utiliser va prendre en entrée les coordonnées des positions et proposer une classification en fonction de ces données.

# %% [markdown]
# Le format des données est le suivant:
# - predictions_entrainement[i] : (17,3)<br>
# - labels_entrainement[i] : (1,2)<br>
#         CORRECT : [1,0];
#         NON_CORRECT : [0,1]

# %%
# Fonction permettant de calculer le centre des hanches de la personne

# entrée : coordonneesXY (BS, 17,3)
# sortie : coordonnées du centre de la hanche [Y, X]
def Calcul_Centre_Hanches(coordonnees):
    hanche_gauche = tf.gather(coordonnees, 11, axis=1)
    hanche_droite = tf.gather(coordonnees, 12, axis=1)
    centre_hanches = 0.5*hanche_gauche + 0.5*hanche_droite
    return centre_hanches  # tenseur (BS,2) : [[Y,X]]

# %%
# Fonction permettant de calculer le centre des épaules de la personne

# entrée : coordonneesXY (BS, 17,3)
# sortie : coordonnées du centre des épaules [Y, X]
def Calcul_Centre_Epaules(coordonnees):
    epaule_gauche = tf.gather(coordonnees, 5, axis=1)
    epaule_droite = tf.gather(coordonnees, 6, axis=1)
    centre_epaules = 0.5*epaule_gauche + 0.5*epaule_droite
    return centre_epaules  # tenseur (BS, 2) : [[Y,X]]

# %%
# Fonction permettant de calculer la taille des coordonnées
# (l'étendue des coordonnées)

# entrée : Coordonnées (BS, 17,2)
# sortie : Maximum en entre :  taille du torse * coefficient_multiplicateur
#                           et distance maximale entre le centre et n'importe quelle coordonnées d'un point de la personne            
def Calcul_Taille_Coordonnees(coordonnees, facteur_multiplicateur_torse=2.5):
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                    # (BS,2) : [[Y,X]]
    
    # Récupère le centre des épaules
    centre_epaules = Calcul_Centre_Epaules(coordonnees)                    # (BS,2) : [[Y,X]]

    # Taille du torse
    taille_torse = tf.linalg.norm(tf.expand_dims(centre_epaules-centre_hanches,1), axis=2)   # (BS,1)
   
    
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                    # (BS,2) : [[Y,X]]
    
    # Création du tenseur pour décaler l'ensemble des coordonnées d'origines
    centre_hanches = tf.expand_dims(centre_hanches, axis=1)                                     # tenseur (BS, 1,2)
    centre_hanches = tf.broadcast_to(centre_hanches, [tf.size(coordonnees) // (13*2), 13, 2])   # tenseur (BS, 17,2)
    
    # Calcul des distances des différents points depuis le centre des hanches
    distances = coordonnees-centre_hanches                 # (BS, 17, 2)
    distances = tf.linalg.norm(distances, axis=2)          # (BS,17)
    
    # Récupère la distance maximale entre le centre des hanches et les points
    max_dist = tf.math.reduce_max(tf.expand_dims(distances,1), axis=2)            # (BS,1)

    # Retourne le maximum entre la distance maximale hanche <=> points
    # et taille du torse*facteur_multiplicatif
    return tf.math.maximum(taille_torse*facteur_multiplicateur_torse, max_dist)

# %%
# Fonction permettant de calculer la taille des coordonnées
# (l'étendue des coordonnées)

# entrée : Coordonnées (BS, 17,2)
# sortie : Maximum en entre :  taille du torse * coefficient_multiplicateur
#                           et distance maximale entre le centre et n'importe quelle coordonnées d'un point de la personne            
def Calcul_Taille_Coordonnees2(coordonnees, facteur_multiplicateur_torse=2.5):
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                    # (BS,2) : [[Y,X]]
    
    # Récupère le centre des épaules
    centre_epaules = Calcul_Centre_Epaules(coordonnees)                    # (BS,2) : [[Y,X]]

    # Taille du torse
    taille_torse = tf.linalg.norm(centre_epaules-centre_hanches) 
   
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                    # (BS,2) : [[Y,X]]
    
    # Création du tenseur pour décaler l'ensemble des coordonnées d'origines
    centre_hanches = tf.expand_dims(centre_hanches, axis=1)                                     # tenseur (BS, 1,2)
    centre_hanches = tf.broadcast_to(centre_hanches, [tf.size(coordonnees) // (coordonnees.shape[1]*2), coordonnees.shape[1], 2])   # tenseur (BS, 17,2)
    
    # Calcul des distances des différents points depuis le centre des hanches
    d = tf.gather(coordonnees - centre_hanches, 0, axis=0, name="dist_to_pose_center")
    
    # Récupère la distance maximale entre le centre des hanches et les points
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Retourne le maximum entre la distance maximale hanche <=> points
    # et taille du torse*facteur_multiplicatif
    return tf.maximum(taille_torse * facteur_multiplicateur_torse, max_dist)

# %%
# Normalisation des données de position 
#  - en translatant le centre des hanches de la personne au coordonnées (0,0)
#  - en redimensionnant les coordonnées de sorte que la taille des coordonnées soit égale à 1

# Entrées :   coordonnees : (BS, 17,3)
def Normalisation_Positions(coordonnees):
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                          # tenseur (BS,2) : [[Y,X]]
    
    # Création du tenseur pour décaler l'ensemble des coordonnées d'origines
    centre_hanches = tf.expand_dims(centre_hanches, axis=1)                                         # tenseur (BS,1,2)
    centre_hanches = tf.broadcast_to(centre_hanches, [tf.size(coordonnees) // (coordonnees.shape[1]*2), coordonnees.shape[1], 2])       # tenseur (BS,17,2)
    
    # Soustraction des coordonnées
    nouvelles_coordonnees = coordonnees - centre_hanches                  # (BS, 17,2)
    
    # Redimensionnement des coordonnées
    taille = Calcul_Taille_Coordonnees2(nouvelles_coordonnees)             # (BS)
    nouvelles_coordonnees = nouvelles_coordonnees / taille                # (BS,17,2)
    
    return nouvelles_coordonnees

# %%
# Traitement des entrées
#  - Translate le centre des hanches de la personne aux coordonnées (0,0)
#  - Normalise la position de sorte que sa taille soit égale à 1
#  - Applatissement du tenseur

# tenseur d'entrée : (BS,17,3)

def traitement_entrees(coordonnees_et_scores):
    # Normalisation des positions
    coordonnees = Normalisation_Positions(coordonnees_et_scores[:,:,:2])          # (BS,17,2)
    
    return coordonnees

# %%
# Définition du modèle
inputs_coordonnees = tf.keras.Input(shape=(17,3), name='input_1')
inputs_coeff = tf.keras.Input(shape=(4), name='input_2')

embedding = traitement_entrees(inputs_coordonnees)                          # (BS,17,2)

inputs_tete = embedding[:,0:5,:]        # (BS,5,2)
inputs_bras = embedding[:,5:11,:]       # (BS,6,2)
inputs_jambes = embedding[:,11:17,:]    # (BS,6,2)


layer_tete = keras.layers.Dense(128, activation=tf.nn.relu6)(keras.layers.Flatten()(inputs_tete))
layer_tete = keras.layers.Dropout(0.5)(layer_tete)
layer_tete = keras.layers.Dense(64, activation=tf.nn.relu6)(layer_tete)
layer_tete = keras.layers.Dropout(0.5)(layer_tete)
outputs_tete = keras.layers.Dense(2, activation="softmax")(layer_tete)

layer_bras = keras.layers.Dense(128, activation=tf.nn.relu6)(keras.layers.Flatten()(inputs_bras))
layer_bras = keras.layers.Dropout(0.5)(layer_bras)
layer_bras = keras.layers.Dense(64, activation=tf.nn.relu6)(layer_bras)
layer_bras = keras.layers.Dropout(0.5)(layer_bras)
outputs_bras = keras.layers.Dense(2, activation="softmax")(layer_bras)

layer_jambes = keras.layers.Dense(128, activation=tf.nn.relu6)(keras.layers.Flatten()(inputs_jambes))
layer_jambes = keras.layers.Dropout(0.5)(layer_jambes)
layer_jambes = keras.layers.Dense(64, activation=tf.nn.relu6)(layer_jambes)
layer_jambes = keras.layers.Dropout(0.5)(layer_jambes)
outputs_jambes = keras.layers.Dense(2, activation="softmax")(layer_jambes)

layer_global = keras.layers.Dense(128, activation=tf.nn.relu6)(keras.layers.Flatten()(embedding))
layer_global = keras.layers.Dropout(0.5)(layer_global)
layer_global = keras.layers.Dense(64, activation=tf.nn.relu6)(layer_global)
layer_global = keras.layers.Dropout(0.5)(layer_global)
outputs_global = keras.layers.Dense(2, activation="softmax")(layer_global)

outputs = inputs_coeff[:,0:1]*outputs_tete+inputs_coeff[:,1:2]*outputs_bras+inputs_coeff[:,2:3]*outputs_jambes+inputs_coeff[:,3:4]*outputs_global
outputs = keras.layers.Dense(2, activation="softmax")(outputs)

model = keras.Model([inputs_coordonnees,inputs_coeff], outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 17, 3)]      0
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 17, 2)        0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather (TFOpLambda (None, 2)            0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_1 (TFOpLamb (None, 2)            0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 2)            0           tf.compat.v1.gather[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 2)            0           tf.math.multiply[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size (TFOpLambda)  ()                   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1, 2)         0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.floor_div (TFOpLam ()                   0           tf.compat.v1.size[0][0]
# __________________________________________________________________________________________________
# tf.broadcast_to (TFOpLambda)    (None, 17, 2)        0           tf.expand_dims[0][0]
#                                                                  tf.compat.v1.floor_div[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 17, 2)        0           tf.__operators__.getitem[0][0]
#                                                                  tf.broadcast_to[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_6 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_7 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 2)            0           tf.math.multiply_6[0][0]
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size_1 (TFOpLambda ()                   0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_4 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_5 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_2 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_3 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 1, 2)         0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.floor_div_1 (TFOpL ()                   0           tf.compat.v1.size_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_3[0][0]
# __________________________________________________________________________________________________
# tf.broadcast_to_1 (TFOpLambda)  (None, 17, 2)        0           tf.expand_dims_1[0][0]
#                                                                  tf.compat.v1.floor_div_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 2)            0           tf.math.multiply_4[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 2)            0           tf.math.multiply_2[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 17, 2)        0           tf.math.subtract[0][0]
#                                                                  tf.broadcast_to_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 2)            0           tf.__operators__.add_2[0][0]
#                                                                  tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_8 (TFOpLamb (17, 2)              0           tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.norm (TFOpLambda)  ()                   0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.norm_1 (TFOpLambda (2,)                 0           tf.compat.v1.gather_8[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) ()                   0           tf.compat.v1.norm[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max (TFOpLambda) ()                   0           tf.compat.v1.norm_1[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum (TFOpLambda)    ()                   0           tf.math.multiply_8[0][0]
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    (None, 17, 2)        0           tf.math.subtract[0][0]
#                                                                  tf.math.maximum[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 5, 2)         0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli (None, 6, 2)         0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 10)           0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 12)           0           tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, 6, 2)         0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1408        flatten[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1664        flatten_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 12)           0           tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          1664        flatten_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 34)           0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          4480        flatten_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           8256        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128)          0           dense_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 1)            0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            130         dropout_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 1)            0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            130         dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           8256        dropout_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 2)            0           tf.__operators__.getitem_4[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None, 2)            0           tf.__operators__.getitem_5[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None, 1)            0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 2)            130         dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 2)            0           tf.math.multiply_9[0][0]
#                                                                  tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 2)            0           tf.__operators__.getitem_6[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (None, 1)            0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            130         dropout_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 2)            0           tf.__operators__.add_4[0][0]
#                                                                  tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 2)            0           tf.__operators__.getitem_7[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 2)            0           tf.__operators__.add_5[0][0]
#                                                                  tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2)            6           tf.__operators__.add_6[0][0]
# ==================================================================================================
# Total params: 42,766
# Trainable params: 42,766
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Entrainement du modèle

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Nombre de périodes d'entrainement
periodes = 1000

# Définition de la fonction d'enregistrement automatique du meilleur modèle
model_save = ModelCheckpoint('meilleur_modele.hdf5', save_best_only=True, monitor='val_loss', mode='max')

# Définition de l'ooptimiseur
adam = keras.optimizers.Adam(learning_rate=1e-3)

# Entrainement du modèle : from_logits=True car on utilise un Softmax en sortie de notre modèle
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

historique = model.fit(x=[tf.convert_to_tensor(predictions_entrainement),
                          tf.transpose(tf.repeat(tf.convert_to_tensor([[1],[1],[1],[1]], dtype=tf.float32),repeats=[tf.convert_to_tensor(predictions_entrainement).shape[0]],axis=1))],
                       y=tf.squeeze(tf.convert_to_tensor(labels_entrainement),1),

                       validation_data=([tf.convert_to_tensor(predictions_validation),
                          tf.transpose(tf.repeat(tf.convert_to_tensor([[1],[1],[1],[1]], dtype=tf.float32),repeats=[tf.convert_to_tensor(predictions_validation).shape[0]],axis=1))],
                                       tf.squeeze(tf.convert_to_tensor(labels_validation),1)), \
                       verbose=1,epochs=periodes,
                       callbacks=[model_save])
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 36s 7s/step - loss: 1.1279 - accuracy: 0.3469 - val_loss: 1.3293 - val_accuracy: 0.1667
# Epoch 2/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 1.0937 - accuracy: 0.3469 - val_loss: 1.2811 - val_accuracy: 0.1667
# Epoch 3/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 1.0670 - accuracy: 0.3469 - val_loss: 1.2323 - val_accuracy: 0.1667
# Epoch 4/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 1.0362 - accuracy: 0.3469 - val_loss: 1.1849 - val_accuracy: 0.1667
# Epoch 5/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 1.0073 - accuracy: 0.3469 - val_loss: 1.1383 - val_accuracy: 0.1667
# Epoch 6/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.9815 - accuracy: 0.3469 - val_loss: 1.0911 - val_accuracy: 0.1667
# Epoch 7/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.9437 - accuracy: 0.3469 - val_loss: 1.0430 - val_accuracy: 0.1667
# Epoch 8/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0
1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.4898 - accuracy: 0.8980 - val_loss: 0.4010 - val_accuracy: 1.0000
# Epoch 130/1000
# 2/2 [==============================] - 0s 122ms/step - loss: 0.4793 - accuracy: 0.8776 - val_loss: 0.3990 - val_accuracy: 1.0000
# Epoch 131/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5050 - accuracy: 0.8571 - val_loss: 0.3967 - val_accuracy: 1.0000
# Epoch 132/1000
# 2/2 [==============================] - 0s 122ms/step - loss: 0.4948 - accuracy: 0.8776 - val_loss: 0.3940 - val_accuracy: 1.0000
# Epoch 133/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.4951 - accuracy: 0.8571 - val_loss: 0.3899 - val_accuracy: 1.0000
# Epoch 134/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4469 - accuracy: 0.9184 - val_loss: 0.3851 - val_accuracy: 1.0000
# Epoch 135/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4746 - accuracy: 0.8367 - val_loss: 0.3795 - val_accuracy: 1.0000
# Epoch 136/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.4632 - accuracy: 0.9184 - val_loss: 0.3756 - val_accuracy: 1.0000
# Epoch 137/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.4495 - accuracy: 0.9388 - val_loss: 0.3726 - val_accuracy: 1.0000
# Epoch 138/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4430 - accuracy: 0.9388 - val_loss: 0.3693 - val_accuracy: 1.0000
# Epoch 139/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.4485 - accuracy: 0.8367 - val_loss: 0.3681 - val_accuracy: 1.0000
# Epoch 140/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4674 - accuracy: 0.8776 - val_loss: 0.3664 - val_accuracy: 1.0000
# Epoch 141/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4391 - accuracy: 0.8980 - val_loss: 0.3653 - val_accuracy: 1.0000
# Epoch 142/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4426 - accuracy: 0.8776 - val_loss: 0.3652 - val_accuracy: 1.0000
# Epoch 143/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4384 - accuracy: 0.8571 - val_loss: 0.3647 - val_accuracy: 1.0000
# Epoch 144/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4526 - accuracy: 0.8776 - val_loss: 0.3604 - val_accuracy: 1.0000
# Epoch 145/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.4237 - accuracy: 0.8776 - val_loss: 0.3552 - val_accuracy: 1.0000
# Epoch 146/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.4470 - accuracy: 0.8776 - val_loss: 0.3512 - val_accuracy: 1.0000
# Epoch 147/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.4329 - accuracy: 0.8776 - val_loss: 0.3481 - val_accuracy: 1.0000
# Epoch 148/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.4386 - accuracy: 0.8776 - val_loss: 0.3454 - val_accuracy: 1.0000
# Epoch 149/1000
# 2/2 [==============================] - 0s 131ms/step - loss: 0.4302 - accuracy: 0.8571 - val_loss: 0.3451 - val_accuracy: 1.0000
# Epoch 150/1000
# 2/2 [==============================] - 0s 128ms/step - loss: 0.4099 - accuracy: 0.9388 - val_loss: 0.3449 - val_accuracy: 1.0000
# Epoch 151/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4140 - accuracy: 0.9388 - val_loss: 0.3436 - val_accuracy: 1.0000
# Epoch 152/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4100 - accuracy: 0.9184 - val_loss: 0.3431 - val_accuracy: 1.0000
# Epoch 153/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4119 - accuracy: 0.9388 - val_loss: 0.3398 - val_accuracy: 1.0000
# Epoch 154/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.3908 - accuracy: 0.9184 - val_loss: 0.3355 - val_accuracy: 1.0000
# Epoch 155/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.3907 - accuracy: 0.9184 - val_loss: 0.3280 - val_accuracy: 1.0000
# Epoch 156/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4067 - accuracy: 0.9184 - val_loss: 0.3216 - val_accuracy: 1.0000
# Epoch 157/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.3950 - accuracy: 0.9388 - val_loss: 0.3160 - val_accuracy: 1.0000
# Epoch 158/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3823 - accuracy: 0.9796 - val_loss: 0.3116 - val_accuracy: 1.0000
# Epoch 159/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3868 - accuracy: 0.8980 - val_loss: 0.3091 - val_accuracy: 1.0000
# Epoch 160/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.3997 - accuracy: 0.9388 - val_loss: 0.3098 - val_accuracy: 1.0000
# Epoch 161/1000
# 2/2 [==============================] - 0s 122ms/step - loss: 0.3898 - accuracy: 0.8980 - val_loss: 0.3138 - val_accuracy: 1.0000
# Epoch 162/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.3762 - accuracy: 0.9388 - val_loss: 0.3159 - val_accuracy: 1.0000
# Epoch 163/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.3744 - accuracy: 0.9184 - val_loss: 0.3159 - val_accuracy: 1.0000
# Epoch 164/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.3844 - accuracy: 0.9592 - val_loss: 0.3124 - val_accuracy: 1.0000
# Epoch 165/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.3657 - accuracy: 0.9388 - val_loss: 0.3067 - val_accuracy: 1.0000
# Epoch 166/1000
# 2/2 [==============================] - 0s 124ms/step - loss: 0.3644 - accuracy: 0.9388 - val_loss: 0.3015 - val_accuracy: 1.0000
# Epoch 167/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.3682 - accuracy: 0.9388 - val_loss: 0.2977 - val_accuracy: 1.0000
# Epoch 168/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.3547 - accuracy: 0.9388 - val_loss: 0.2967 - val_accuracy: 1.0000
# Epoch 169/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.3651 - accuracy: 0.8980 - val_loss: 0.2968 - val_accuracy: 1.0000
# Epoch 170/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3394 - accuracy: 1.0000 - val_loss: 0.2969 - val_accuracy: 1.0000
# Epoch 171/1000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.3398 - accuracy: 0.9388 - val_loss: 0.2995 - val_accuracy: 1.0000
# Epoch 172/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3404 - accuracy: 0.9592 - val_loss: 0.2996 - val_accuracy: 1.0000
# Epoch 173/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.3577 - accuracy: 0.9592 - val_loss: 0.2947 - val_accuracy: 1.0000
# Epoch 174/1000
# 2/2 [==============================] - 0s 136ms/step - loss: 0.3369 - accuracy: 0.9388 - val_loss: 0.2856 - val_accuracy: 1.0000
# Epoch 175/1000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.3455 - accuracy: 0.9592 - val_loss: 0.2743 - val_accuracy: 1.0000
# Epoch 176/1000
# 2/2 [==============================] - 0s 123ms/step - loss: 0.3354 - accuracy: 0.9388 - val_loss: 0.2693 - val_accuracy: 1.0000
# Epoch 177/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.3263 - accuracy: 0.9388 - val_loss: 0.2662 - val_accuracy: 1.0000
# Epoch 178/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.3306 - accuracy: 0.9388 - val_loss: 0.2634 - val_accuracy: 1.0000
# Epoch 179/1000
# 2/2 [==============================] - 0s 122ms/step - loss: 0.3190 - accuracy: 0.9592 - val_loss: 0.2606 - val_accuracy: 1.0000
# Epoch 180/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.3089 - accuracy: 0.9592 - val_loss: 0.2570 - val_accuracy: 1.0000
# Epoch 181/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.3223 - accuracy: 0.9184 - val_loss: 0.2573 - val_accuracy: 1.0000
# Epoch 182/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.3353 - accuracy: 0.9184 - val_loss: 0.2633 - val_accuracy: 1.0000
# Epoch 183/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3119 - accuracy: 0.9592 - val_loss: 0.2723 - val_accuracy: 1.0000
# Epoch 184/1000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.3291 - accuracy: 0.8980 - val_loss: 0.2778 - val_accuracy: 1.0000
# Epoch 185/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.3095 - accuracy: 0.9388 - val_loss: 0.2757 - val_accuracy: 1.0000
# Epoch 186/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.3282 - accuracy: 0.9184 - val_loss: 0.2702 - val_accuracy: 1.0000
# Epoch 187/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.3037 - accuracy: 0.9592 - val_loss: 0.2644 - val_accuracy: 1.0000
# Epoch 188/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.3085 - accuracy: 0.9184 - val_loss: 0.2565 - val_accuracy: 1.0000
# Epoch 189/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.3198 - accuracy: 0.9388 - val_loss: 0.2497 - val_accuracy: 1.0000
# Epoch 190/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3063 - accuracy: 0.9388 - val_loss: 0.2448 - val_accuracy: 1.0000
# Epoch 191/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3166 - accuracy: 0.9184 - val_loss: 0.2431 - val_accuracy: 1.0000
# Epoch 192/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.3053 - accuracy: 0.9388 - val_loss: 0.2462 - val_accuracy: 1.0000
# Epoch 193/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.2985 - accuracy: 0.9388 - val_loss: 0.2499 - val_accuracy: 1.0000
# Epoch 194/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.3079 - accuracy: 0.9388 - val_loss: 0.2486 - val_accuracy: 1.0000
# Epoch 195/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.2750 - accuracy: 0.9388 - val_loss: 0.2445 - val_accuracy: 1.0000
# Epoch 196/1000
# 2/2 [==============================] - 0s 130ms/step - loss: 0.2801 - accuracy: 0.9592 - val_loss: 0.2366 - val_accuracy: 1.0000
# Epoch 197/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2899 - accuracy: 0.9388 - val_loss: 0.2277 - val_accuracy: 1.0000
# Epoch 198/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2939 - accuracy: 0.9388 - val_loss: 0.2213 - val_accuracy: 1.0000
# Epoch 199/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2733 - accuracy: 0.9796 - val_loss: 0.2196 - val_accuracy: 1.0000
# Epoch 200/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.2673 - accuracy: 0.9796 - val_loss: 0.2242 - val_accuracy: 1.0000
# Epoch 201/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2861 - accuracy: 0.9388 - val_loss: 0.2269 - val_accuracy: 1.0000
# Epoch 202/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2862 - accuracy: 0.9388 - val_loss: 0.2280 - val_accuracy: 1.0000
# Epoch 203/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2642 - accuracy: 0.9592 - val_loss: 0.2241 - val_accuracy: 1.0000
# Epoch 204/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2862 - accuracy: 0.9184 - val_loss: 0.2173 - val_accuracy: 1.0000
# Epoch 205/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2611 - accuracy: 0.9796 - val_loss: 0.2165 - val_accuracy: 1.0000
# Epoch 206/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2674 - accuracy: 0.9592 - val_loss: 0.2151 - val_accuracy: 1.0000
# Epoch 207/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2644 - accuracy: 0.9592 - val_loss: 0.2118 - val_accuracy: 1.0000
# Epoch 208/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.2621 - accuracy: 0.9592 - val_loss: 0.2087 - val_accuracy: 1.0000
# Epoch 209/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2623 - accuracy: 0.9796 - val_loss: 0.2049 - val_accuracy: 1.0000
# Epoch 210/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2861 - accuracy: 0.9592 - val_loss: 0.2030 - val_accuracy: 1.0000
# Epoch 211/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2692 - accuracy: 0.9388 - val_loss: 0.2049 - val_accuracy: 1.0000
# Epoch 212/1000
# 2/2 [==============================] - 0s 123ms/step - loss: 0.2483 - accuracy: 0.9796 - val_loss: 0.2084 - val_accuracy: 1.0000
# Epoch 213/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.2722 - accuracy: 0.9388 - val_loss: 0.2084 - val_accuracy: 1.0000
# Epoch 214/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.2539 - accuracy: 0.9796 - val_loss: 0.2075 - val_accuracy: 1.0000
# Epoch 215/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.2549 - accuracy: 0.9592 - val_loss: 0.2079 - val_accuracy: 1.0000
# Epoch 216/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.2473 - accuracy: 0.9592 - val_loss: 0.2090 - val_accuracy: 1.0000
# Epoch 217/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2316 - accuracy: 0.9796 - val_loss: 0.2069 - val_accuracy: 1.0000
# Epoch 218/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.2496 - accuracy: 0.9796 - val_loss: 0.2026 - val_accuracy: 1.0000
# Epoch 219/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2515 - accuracy: 0.9592 - val_loss: 0.1961 - val_accuracy: 1.0000
# Epoch 220/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.2498 - accuracy: 0.9796 - val_loss: 0.1919 - val_accuracy: 1.0000
# Epoch 221/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2417 - accuracy: 0.9388 - val_loss: 0.1881 - val_accuracy: 1.0000
# Epoch 222/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2314 - accuracy: 0.9388 - val_loss: 0.1854 - val_accuracy: 1.0000
# Epoch 223/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.2634 - accuracy: 0.9592 - val_loss: 0.1820 - val_accuracy: 1.0000
# Epoch 224/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.2535 - accuracy: 0.9796 - val_loss: 0.1856 - val_accuracy: 1.0000
# Epoch 225/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2491 - accuracy: 0.9796 - val_loss: 0.1907 - val_accuracy: 1.0000
# Epoch 226/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.2209 - accuracy: 0.9592 - val_loss: 0.1901 - val_accuracy: 1.0000
# Epoch 227/1000
# 2/2 [==============================] - 0s 122ms/step - loss: 0.2308 - accuracy: 0.9592 - val_loss: 0.1879 - val_accuracy: 1.0000
# Epoch 228/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.2230 - accuracy: 0.9796 - val_loss: 0.1844 - val_accuracy: 1.0000
# Epoch 229/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2499 - accuracy: 0.9388 - val_loss: 0.1800 - val_accuracy: 1.0000
# Epoch 230/1000
# 2/2 [==============================] - 0s 133ms/step - loss: 0.2335 - accuracy: 0.9796 - val_loss: 0.1803 - val_accuracy: 1.0000
# Epoch 231/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2252 - accuracy: 0.9592 - val_loss: 0.1815 - val_accuracy: 1.0000
# Epoch 232/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.2136 - accuracy: 0.9796 - val_loss: 0.1811 - val_accuracy: 1.0000
# Epoch 233/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2277 - accuracy: 0.9592 - val_loss: 0.1779 - val_accuracy: 1.0000
# Epoch 234/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2315 - accuracy: 0.9592 - val_loss: 0.1778 - val_accuracy: 1.0000
# Epoch 235/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2190 - accuracy: 0.9592 - val_loss: 0.1818 - val_accuracy: 1.0000
# Epoch 236/1000
# 2/2 [==============================] - 0s 122ms/step - loss: 0.2315 - accuracy: 0.9592 - val_loss: 0.1835 - val_accuracy: 1.0000
# Epoch 237/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.2120 - accuracy: 0.9796 - val_loss: 0.1831 - val_accuracy: 1.0000
# Epoch 238/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2219 - accuracy: 0.9592 - val_loss: 0.1750 - val_accuracy: 1.0000
# Epoch 239/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2137 - accuracy: 0.9388 - val_loss: 0.1649 - val_accuracy: 1.0000
# Epoch 240/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1990 - accuracy: 0.9796 - val_loss: 0.1594 - val_accuracy: 1.0000
# Epoch 241/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.2212 - accuracy: 0.9796 - val_loss: 0.1563 - val_accuracy: 1.0000
# Epoch 242/1000
# 2/2 [==============================] - 0s 125ms/step - loss: 0.2164 - accuracy: 0.9796 - val_loss: 0.1552 - val_accuracy: 1.0000
# Epoch 243/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.2167 - accuracy: 0.9796 - val_loss: 0.1578 - val_accuracy: 1.0000
# Epoch 244/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.2198 - accuracy: 0.9388 - val_loss: 0.1661 - val_accuracy: 1.0000
# Epoch 245/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2354 - accuracy: 0.9592 - val_loss: 0.1677 - val_accuracy: 1.0000
# Epoch 246/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2261 - accuracy: 0.9592 - val_loss: 0.1683 - val_accuracy: 1.0000
# Epoch 247/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.2266 - accuracy: 0.9592 - val_loss: 0.1647 - val_accuracy: 1.0000
# Epoch 248/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2305 - accuracy: 0.9796 - val_loss: 0.1608 - val_accuracy: 1.0000
# Epoch 249/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.2155 - accuracy: 0.9796 - val_loss: 0.1604 - val_accuracy: 1.0000
# Epoch 250/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2083 - accuracy: 0.9796 - val_loss: 0.1625 - val_accuracy: 1.0000
# Epoch 251/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2132 - accuracy: 0.9592 - val_loss: 0.1601 - val_accuracy: 1.0000
# Epoch 252/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2150 - accuracy: 0.9592 - val_loss: 0.1606 - val_accuracy: 1.0000
# Epoch 253/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2222 - accuracy: 0.9592 - val_loss: 0.1632 - val_accuracy: 1.0000
# Epoch 254/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2312 - accuracy: 0.9592 - val_loss: 0.1671 - val_accuracy: 1.0000
# Epoch 255/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.2249 - accuracy: 0.9592 - val_loss: 0.1693 - val_accuracy: 1.0000
# Epoch 256/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.1945 - accuracy: 0.9796 - val_loss: 0.1691 - val_accuracy: 1.0000
# Epoch 257/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.2002 - accuracy: 0.9592 - val_loss: 0.1654 - val_accuracy: 1.0000
# Epoch 258/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2083 - accuracy: 0.9796 - val_loss: 0.1594 - val_accuracy: 1.0000
# Epoch 259/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1829 - accuracy: 0.9796 - val_loss: 0.1560 - val_accuracy: 1.0000
# Epoch 260/1000
# 2/2 [==============================] - 0s 123ms/step - loss: 0.1926 - accuracy: 0.9796 - val_loss: 0.1483 - val_accuracy: 1.0000
# Epoch 261/1000
# 2/2 [==============================] - 0s 123ms/step - loss: 0.1954 - accuracy: 0.9796 - val_loss: 0.1426 - val_accuracy: 1.0000
# Epoch 262/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.2036 - accuracy: 0.9592 - val_loss: 0.1400 - val_accuracy: 1.0000
# Epoch 263/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2067 - accuracy: 0.9796 - val_loss: 0.1389 - val_accuracy: 1.0000
# Epoch 264/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1932 - accuracy: 0.9592 - val_loss: 0.1416 - val_accuracy: 1.0000
# Epoch 265/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1969 - accuracy: 0.9796 - val_loss: 0.1499 - val_accuracy: 1.0000
# Epoch 266/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.2072 - accuracy: 0.9796 - val_loss: 0.1623 - val_accuracy: 1.0000
# Epoch 267/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1976 - accuracy: 0.9796 - val_loss: 0.1660 - val_accuracy: 1.0000
# Epoch 268/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1901 - accuracy: 0.9796 - val_loss: 0.1628 - val_accuracy: 1.0000
# Epoch 269/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1984 - accuracy: 0.9796 - val_loss: 0.1531 - val_accuracy: 1.0000
# Epoch 270/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1856 - accuracy: 0.9796 - val_loss: 0.1428 - val_accuracy: 1.0000
# Epoch 271/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.2082 - accuracy: 0.9592 - val_loss: 0.1328 - val_accuracy: 1.0000
# Epoch 272/1000
# 2/2 [==============================] - 0s 124ms/step - loss: 0.1915 - accuracy: 0.9796 - val_loss: 0.1302 - val_accuracy: 1.0000
# Epoch 273/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1641 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 1.0000
# Epoch 274/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.1907 - accuracy: 0.9796 - val_loss: 0.1325 - val_accuracy: 1.0000
# Epoch 275/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1799 - accuracy: 0.9796 - val_loss: 0.1361 - val_accuracy: 1.0000
# Epoch 276/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1922 - accuracy: 0.9388 - val_loss: 0.1352 - val_accuracy: 1.0000
# Epoch 277/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1883 - accuracy: 0.9796 - val_loss: 0.1331 - val_accuracy: 1.0000
# Epoch 278/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1760 - accuracy: 0.9796 - val_loss: 0.1314 - val_accuracy: 1.0000
# Epoch 279/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.1833 - accuracy: 0.9796 - val_loss: 0.1341 - val_accuracy: 1.0000
# Epoch 280/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1796 - accuracy: 0.9796 - val_loss: 0.1380 - val_accuracy: 1.0000
# Epoch 281/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1794 - accuracy: 0.9592 - val_loss: 0.1383 - val_accuracy: 1.0000
# Epoch 282/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1823 - accuracy: 0.9592 - val_loss: 0.1352 - val_accuracy: 1.0000
# Epoch 283/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1946 - accuracy: 0.9592 - val_loss: 0.1317 - val_accuracy: 1.0000
# Epoch 284/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.1860 - accuracy: 0.9388 - val_loss: 0.1280 - val_accuracy: 1.0000
# Epoch 285/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.1869 - accuracy: 0.9796 - val_loss: 0.1272 - val_accuracy: 1.0000
# Epoch 286/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1924 - accuracy: 0.9592 - val_loss: 0.1269 - val_accuracy: 1.0000
# Epoch 287/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1796 - accuracy: 0.9592 - val_loss: 0.1285 - val_accuracy: 1.0000
# Epoch 288/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1607 - accuracy: 0.9796 - val_loss: 0.1293 - val_accuracy: 1.0000
# Epoch 289/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.1616 - accuracy: 0.9796 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 290/1000
# 2/2 [==============================] - 0s 126ms/step - loss: 0.1616 - accuracy: 0.9796 - val_loss: 0.1214 - val_accuracy: 1.0000
# Epoch 291/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1587 - accuracy: 0.9796 - val_loss: 0.1198 - val_accuracy: 1.0000
# Epoch 292/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.1615 - accuracy: 0.9592 - val_loss: 0.1199 - val_accuracy: 1.0000
# Epoch 293/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1817 - accuracy: 0.9388 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 294/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1852 - accuracy: 0.9592 - val_loss: 0.1356 - val_accuracy: 1.0000
# Epoch 295/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1834 - accuracy: 0.9592 - val_loss: 0.1375 - val_accuracy: 1.0000
# Epoch 296/1000
# 2/2 [==============================] - 0s 123ms/step - loss: 0.1778 - accuracy: 0.9592 - val_loss: 0.1340 - val_accuracy: 1.0000
# Epoch 297/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1794 - accuracy: 0.9592 - val_loss: 0.1287 - val_accuracy: 1.0000
# Epoch 298/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.1738 - accuracy: 0.9796 - val_loss: 0.1231 - val_accuracy: 1.0000
# Epoch 299/1000
# 2/2 [==============================] - 0s 122ms/step - loss: 0.1724 - accuracy: 0.9592 - val_loss: 0.1222 - val_accuracy: 1.0000
# Epoch 300/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1568 - accuracy: 0.9796 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 301/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1483 - accuracy: 0.9796 - val_loss: 0.1228 - val_accuracy: 1.0000
# Epoch 302/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1811 - accuracy: 0.9796 - val_loss: 0.1197 - val_accuracy: 1.0000
# Epoch 303/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.1715 - accuracy: 0.9796 - val_loss: 0.1166 - val_accuracy: 1.0000
# Epoch 304/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1362 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 1.0000
# Epoch 305/1000
# 2/2 [==============================] - 0s 109ms/step - loss: 0.1602 - accuracy: 0.9796 - val_loss: 0.1064 - val_accuracy: 1.0000
# Epoch 306/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1572 - accuracy: 0.9796 - val_loss: 0.1028 - val_accuracy: 1.0000
# Epoch 307/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1674 - accuracy: 0.9796 - val_loss: 0.1000 - val_accuracy: 1.0000
# Epoch 308/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1884 - accuracy: 0.9592 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 309/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.1549 - accuracy: 0.9592 - val_loss: 0.1052 - val_accuracy: 1.0000
# Epoch 310/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.1593 - accuracy: 0.9796 - val_loss: 0.1127 - val_accuracy: 1.0000
# Epoch 311/1000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1870 - accuracy: 0.9796 - val_loss: 0.1175 - val_accuracy: 1.0000
# Epoch 312/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.
1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0672 - accuracy: 0.9796 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 934/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0644 - accuracy: 0.9796 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 935/1000
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0743 - accuracy: 0.9796 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 936/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0708 - accuracy: 0.9796 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 937/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0571 - accuracy: 0.9796 - val_loss: 0.0234 - val_accuracy: 1.0000
# Epoch 938/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1129 - accuracy: 0.9796 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 939/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 940/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0711 - accuracy: 0.9796 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 941/1000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0631 - accuracy: 0.9796 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 942/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0893 - accuracy: 0.9592 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 943/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 944/1000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0609 - accuracy: 0.9796 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 945/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 946/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0508 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 947/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 948/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0756 - accuracy: 0.9592 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 949/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0586 - accuracy: 0.9796 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 950/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 951/1000
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0597 - accuracy: 0.9796 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 952/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0466 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 953/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 954/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0358 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 955/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0470 - accuracy: 0.9796 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 956/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 957/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0634 - accuracy: 0.9796 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 958/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0670 - accuracy: 0.9796 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 959/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0453 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 960/1000
# 2/2 [==============================] - 0s 124ms/step - loss: 0.0385 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 961/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0554 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 962/1000
# 2/2 [==============================] - 0s 124ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 963/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0749 - accuracy: 0.9796 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 964/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0823 - accuracy: 0.9796 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 965/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0909 - accuracy: 0.9796 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 966/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 967/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0583 - accuracy: 0.9796 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 968/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 969/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 970/1000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 971/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 972/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 973/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 974/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0778 - accuracy: 0.9796 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 975/1000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0626 - accuracy: 0.9796 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 976/1000
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0811 - accuracy: 0.9796 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 977/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0436 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 978/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0484 - accuracy: 0.9796 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 979/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 980/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 981/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0700 - accuracy: 0.9796 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 982/1000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0460 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 983/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0572 - accuracy: 0.9796 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 984/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 985/1000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0723 - accuracy: 0.9796 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 986/1000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0572 - accuracy: 0.9796 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 987/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0566 - accuracy: 0.9796 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 988/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 989/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0466 - accuracy: 0.9796 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 990/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0598 - accuracy: 0.9796 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 991/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0501 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 992/1000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0657 - accuracy: 0.9796 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 993/1000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0437 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 994/1000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1041 - accuracy: 0.9592 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 995/1000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0609 - accuracy: 0.9796 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 996/1000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0666 - accuracy: 0.9592 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 997/1000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0584 - accuracy: 0.9796 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 998/1000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0446 - accuracy: 0.9796 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 999/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 1000/1000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0675 - accuracy: 0.9796 - val_loss: 0.0167 - val_accuracy: 1.0000

# %%
# Affichage de la progression de l'entrainement

plt.plot(historique.history['accuracy'])
plt.plot(historique.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('précision (%)')
plt.xlabel("période d'entrainement")
plt.legend(['Entrainement', 'Validation'], loc='lower right')
plt.show()

# %% [markdown]
# # Tests du modèle sur les données de validation

# %% [markdown]
# labels_validation[index]Les probabilités du label CORRECT sont affichées entre crochets :

# %%
plt.figure(figsize=(10, 10))

for i in range(8):
    ax = plt.subplot(4, 4, i + 1)
    index = np.random.randint(0,len(dataset_validation))
    image = keras.utils.array_to_img(images_validation[index][0])
    image = np.array(image)
    draw_image = draw_lines(image, predictions_validation[index])
    
    pred = model([tf.expand_dims(tf.convert_to_tensor(predictions_validation)[index],0),
                 tf.convert_to_tensor([[1.0,1.0,1.0,1.0]], dtype=tf.float32)])
    
    plt.imshow(draw_image.astype("uint8"))
    plt.title(class_names[np.argmax(labels_validation[index], axis=None, out=None)]+" [%.1f]" %(pred.numpy()[0][0]))
    plt.axis("off")

# %% [markdown]
# # Sauvegarde du modèle

# %%
# !mkdir "SaveModel2"

# %%
tf.saved_model.save(model,"/home/jetson/notebook/Olympiades2024/3. Model_Classification/SaveModel2")
