# %% [markdown]
# # Entrainement du modèle
#
# Dans ce notebook, nous allons entrainer notre modèle afin qu'il puisse classifier les positions capturées avec la caméra dans les classes ``correct`` ou ``non correcte``. Le modèle que nous allons utiliser est dérivé du modèle MoveNet.
#
# Nous allons utiliser la librairie Keras / Tensorflow pour créer notre modèle.

# %%
import tensorflow as tf
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm

from tensorflow import keras
from matplotlib import pyplot as plt

# %% [markdown]
# ### Téléchargement et extraction des données collectées
#
# Tout d'abord il faut récupérer les données collectées contenues dans le fichier ``dataset.zip`` que nous avons créé précedemment. Pour cela, il suffit d'exécuter la commande ci-dessous.

# %%
# !unzip -q dataset.zip

# %% [markdown]
# Un dossier nommé ``dataset`` devrait apparaître dans l'explorateur de fichiers.

# %% [markdown]
# # Création des datasets

# %% [markdown]
# ### Chargement des images dans le dataset d'entrainement

# %% [markdown]
# A partir des images sauvegardées dans le répertoire de travail, on peut maintenant créer notre dataset. On commence par créer une liste contenant les deux classes utilisées :

# %%
nom_position = "Corbeau"

CATEGORIES = ['correct', 'non_correct']
datasets = {}
for name in CATEGORIES:
    datasets[name] = []

# %% [markdown]
# On charge ensuite les données à l'aide de la fonction ``image_dataset_from_directory`` de Keras, en précisant la résolution des images et le type de label associé (ici on utilise le type ``categorical`` - voir ci-dessous). On demande également d'utiliser un ``batch size`` de 1 et d'utiliser 90% des images pour l'entrainement et les 10% restant pour les validations :

# %%
# Récupère le répertoire courant
repertoire_courant = os.getcwd()

# Création du dataset d'entrainement
dataset_entrainement = tf.keras.preprocessing.image_dataset_from_directory(
    repertoire_courant + "/dataset/" + nom_position + "/",
    validation_split=0.2,
    subset="training",
    image_size=(256, 256),
    batch_size=1,
    shuffle=True,
    seed=123,
    label_mode='categorical')

# Création du dataset de validation
dataset_validation = tf.keras.preprocessing.image_dataset_from_directory(
    repertoire_courant + "/dataset/" + nom_position + "/",
    validation_split=0.2,
    subset="validation",
    image_size=(256, 256),
    batch_size=1,
    shuffle=True,
    seed=123,
    label_mode='categorical')
# Out:
# Found 61 files belonging to 2 classes.
# Using 49 files for training.
# Found 61 files belonging to 2 classes.
# Using 12 files for validation.

# %%
# Extraciton des tenseurs depuis le dataset
images_entrainement, labels_entrainement = tuple(zip(*dataset_entrainement))
images_validation, labels_validation = tuple(zip(*dataset_validation))

# %% [markdown]
# Observons le nom des classes utilisées :

# %%
class_names = dataset_entrainement.class_names
print(class_names)
# Out:
# ['CORRECT', 'NON_CORRECT']

# %% [markdown]
# Regardons le format du tenseur contenu dans le dataset :

# %%
for image,label in dataset_entrainement.take(2):
    print(image.shape)
    print(label.shape)
# Out:
# (1, 256, 256, 3)
# (1, 2)
# (1, 256, 256, 3)
# (1, 2)

# %% [markdown]
# Affichons quelques labels codé de manière "categorical" et leur valeur équivalente "binaire" :

# %%
for image,label in dataset_entrainement.take(5):
    print("Label categorical : %s" %label[0])
    print("Label binaire correspondant : %s" %np.argmax(label[0], axis=None, out=None))
    print("Classe correspondante : %s" %class_names[np.argmax(label[0], axis=None, out=None)])
    print("")
# Out:
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT
#
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT
#
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT
#
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT
#
# Label categorical : tf.Tensor([0. 1.], shape=(2,), dtype=float32)
# Label binaire correspondant : 1
# Classe correspondante : NON_CORRECT

# %% [markdown]
# Affichons maintenant quelques images :

# %%
plt.figure(figsize=(10, 10))

for i in range(8):
    index = np.random.randint(0,len(dataset_entrainement))
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images_entrainement[index][0].numpy().astype("uint8"))
    plt.title(class_names[np.argmax(labels_entrainement[index][0], axis=None, out=None)])
    plt.axis("off")

# %% [markdown]
# On va maintenant utiliser le modèle MoveNet pour créer les données d'entrées pour l'entrainement

# %%
import tensorrt as trt
import pycuda.driver as cuda
import pycuda.autoinit

PRECISION = trt.int32

# Construction de la class du logger
class MyLogger(trt.ILogger):
    def __init__(self):
        trt.ILogger.__init__(self)

    def log(self, severity, msg):
        print("%s : %s" %(severity,msg))
        pass

logger = MyLogger()
runtime = trt.Runtime(logger)

with open("model_jetson.engine", "rb") as f:
    engine = runtime.deserialize_cuda_engine(f.read())

context = engine.create_execution_context()

# Réservation de la mémoire pour l'entrée
size_input = trt.volume(engine.get_binding_shape(0))* engine.max_batch_size
input_host_mem = cuda.pagelocked_empty(size_input, trt.nptype(PRECISION))
input_device_mem = cuda.mem_alloc(input_host_mem.nbytes)

# Réservation de la mémoire pour les sorties
output_device_mem = [];
format_sorties = [];
types_sorties = [];

for i in range(engine.num_bindings):
    if not engine.binding_is_input(i):
        size_output = trt.volume(engine.get_binding_shape(i))* engine.max_batch_size
        output_host_mem = cuda.pagelocked_empty(size_output, trt.nptype(PRECISION))
        output_device_mem.append(cuda.mem_alloc(output_host_mem.nbytes))
        format_sorties.append(engine.get_binding_shape(i))
        types_sorties.append(trt.nptype(engine.get_binding_dtype(i)))

# Récupère les adresses en GPU des buffers entrées / sorties
binding_entree = int(input_device_mem)

binding_sorties = []
for output_ in output_device_mem:
    binding_sorties.append(int(output_))

# Initialise le moteur
print("Initialisation du moteur..")
x = images_entrainement[0].numpy().astype(np.int32)
np.copyto(input_host_mem,x.ravel())
cuda.memcpy_htod(input_device_mem, input_host_mem)
bindings = [binding_entree, binding_sorties[0]]
context.execute_v2(bindings=bindings)
# Out:
# Severity.INFO : [MemUsageChange] Init CUDA: CPU +225, GPU +0, now: CPU 866, GPU 3411 (MiB)
# Severity.INFO : Loaded engine size: 16 MiB
# Severity.WARNING : Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# Severity.VERBOSE : Using cublas as a tactic source
# Severity.INFO : [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +158, GPU +197, now: CPU 1043, GPU 3658 (MiB)
# Severity.VERBOSE : Using cuDNN as a tactic source
# Severity.INFO : [MemUsageChange] Init cuDNN: CPU +240, GPU +17, now: CPU 1283, GPU 3675 (MiB)
# Severity.VERBOSE : Deserialization required 5068757 microseconds.
# Severity.INFO : [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +14, now: CPU 0, GPU 14 (MiB)
# Severity.VERBOSE : Using cublas as a tactic source
# Severity.INFO : [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU -1, now: CPU 1267, GPU 3656 (MiB)
# Severity.VERBOSE : Using cuDNN as a tactic source
# Severity.INFO : [MemUsageChange] Init cuDNN: CPU +0, GPU +0, now: CPU 1267, GPU 3656 (MiB)
# Severity.VERBOSE : Total per-runner device persistent memory is 13678592
# Severity.VERBOSE : Total per-runner host persistent memory is 157056
# Severity.VERBOSE : Allocated activation device memory of size 18387456
# Severity.INFO : [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +30, now: CPU 0, GPU 44 (MiB)
# Initialisation du moteur..
# True

# %%
predictions_entrainement = []
predictions_validation = []

for i in tqdm(range(len(dataset_entrainement))):
    x = images_entrainement[i].numpy().astype(np.int32)
    np.copyto(input_host_mem,x.ravel())
    cuda.memcpy_htod(input_device_mem, input_host_mem)
    bindings = [binding_entree, binding_sorties[0]]
    context.execute_v2(bindings=bindings)
    output_host_mem = np.zeros(format_sorties[0],types_sorties[0])
    cuda.memcpy_dtoh(output_host_mem[0], output_device_mem[0])
    predictions_entrainement.append(output_host_mem[0][0])

for i in tqdm(range(len(dataset_validation))):
    x = images_validation[i].numpy().astype(np.int32)
    np.copyto(input_host_mem,x.ravel())
    cuda.memcpy_htod(input_device_mem, input_host_mem)
    bindings = [binding_entree, binding_sorties[0]]
    context.execute_v2(bindings=bindings)
    output_host_mem = np.zeros(format_sorties[0],types_sorties[0])
    cuda.memcpy_dtoh(output_host_mem[0], output_device_mem[0])
    predictions_validation.append(output_host_mem[0][0])
# Out:
# 100%|██████████| 49/49 [00:01<00:00, 25.20it/s]
# 100%|██████████| 12/12 [00:00<00:00, 26.41it/s]

# %% [markdown]
# # Vérification des positions

# %%
import cv2

def draw_lines(img_cv2, coordonneesXY, line_width=1):
    width, height = (256,256)

    nez = [int(coordonneesXY[0][1]*width),int(coordonneesXY[0][0]*height)]
    oeuil_gauche = [int(coordonneesXY[1][1]*width),int(coordonneesXY[1][0]*height)]
    oeuil_droit = [int(coordonneesXY[2][1]*width),int(coordonneesXY[2][0]*height)]
    oreille_gauche = [int(coordonneesXY[3][1]*width),int(coordonneesXY[3][0]*height)]
    oreille_droite = [int(coordonneesXY[4][1]*width),int(coordonneesXY[4][0]*height)]
    epaule_gauche = [int(coordonneesXY[5][1]*width),int(coordonneesXY[5][0]*height)]
    epaule_droite = [int(coordonneesXY[6][1]*width),int(coordonneesXY[6][0]*height)]
    coude_gauche = [int(coordonneesXY[7][1]*width),int(coordonneesXY[7][0]*height)]
    coude_droite = [int(coordonneesXY[8][1]*width),int(coordonneesXY[8][0]*height)]
    poignet_gauche = [int(coordonneesXY[9][1]*width),int(coordonneesXY[9][0]*height)]
    poignet_droite = [int(coordonneesXY[10][1]*width),int(coordonneesXY[10][0]*height)]
    hanche_gauche = [int(coordonneesXY[11][1]*width),int(coordonneesXY[11][0]*height)]
    hanche_droite = [int(coordonneesXY[12][1]*width),int(coordonneesXY[12][0]*height)]
    genou_gauche = [int(coordonneesXY[13][1]*width),int(coordonneesXY[13][0]*height)]
    genou_droite = [int(coordonneesXY[14][1]*width),int(coordonneesXY[14][0]*height)]
    cheville_gauche = [int(coordonneesXY[15][1]*width),int(coordonneesXY[15][0]*height)]
    cheville_droite = [int(coordonneesXY[16][1]*width),int(coordonneesXY[16][0]*height)]


    centre_yeux = [((int(0.5*(coordonneesXY[1][1]*width+int(coordonneesXY[2][1]*width))))),((int(0.5*(coordonneesXY[1][0]*height+int(coordonneesXY[2][0]*height)))))]
    centre_epaules = [((int(0.5*(coordonneesXY[5][1]*width+int(coordonneesXY[6][1]*width))))),((int(0.5*(coordonneesXY[5][0]*height+int(coordonneesXY[6][0]*height)))))]
    centre_hanches =  [((int(0.5*(coordonneesXY[11][1]*width+int(coordonneesXY[12][1]*width))))),((int(0.5*(coordonneesXY[11][0]*height+int(coordonneesXY[12][0]*height)))))]


    # Lignes nez-centre des yeux
    img = cv2.line(img_cv2, (nez[0],nez[1]),(centre_yeux[0],centre_yeux[1]),color=(0, 0, 255), thickness=2)

    # Lignes centre des yeux - oueil gauche
    img = cv2.line(img_cv2, (oeuil_gauche[0],oeuil_gauche[1]),(centre_yeux[0],centre_yeux[1]),color=(0, 0, 255), thickness=2)

    # Lignes centre des yeux - oueil droit
    img = cv2.line(img_cv2, (oeuil_droit[0],oeuil_droit[1]),(centre_yeux[0],centre_yeux[1]),color=(0, 0, 255), thickness=2)

    # Lignes oeuil_gauche - oreille gauche
    img = cv2.line(img_cv2, (oeuil_gauche[0],oeuil_gauche[1]),(oreille_gauche[0],oreille_gauche[1]),color=(0, 0, 255), thickness=2)

    # Lignes oeuil_droit - oreille droite
    img = cv2.line(img_cv2, (oeuil_droit[0],oeuil_droit[1]),(oreille_droite[0],oreille_droite[1]),color=(0, 0, 255), thickness=2)

    # Lignes nez-centre_epaules
    img = cv2.line(img_cv2, (nez[0],nez[1]),(centre_epaules[0],centre_epaules[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_epaules - epaule_droit
    img = cv2.line(img_cv2, (epaule_droite[0],epaule_droite[1]),(centre_epaules[0],centre_epaules[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_epaules - epaule_gauche
    img = cv2.line(img_cv2, (epaule_gauche[0],epaule_gauche[1]),(centre_epaules[0],centre_epaules[1]),color=(0, 0, 255), thickness=2)

    # Ligne épaule_gauche - coude_gouche
    img = cv2.line(img_cv2, (epaule_gauche[0],epaule_gauche[1]),(coude_gauche[0],coude_gauche[1]),color=(0, 0, 255), thickness=2)

    # Ligne coude_gouche - poignet_gauche
    img = cv2.line(img_cv2, (poignet_gauche[0],poignet_gauche[1]),(coude_gauche[0],coude_gauche[1]),color=(0, 0, 255), thickness=2)

    # Ligne épaule_droite - coude_doit
    img = cv2.line(img_cv2, (epaule_droite[0],epaule_droite[1]),(coude_droite[0],coude_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne coude_droite - poignet_droite
    img = cv2.line(img_cv2, (poignet_droite[0],poignet_droite[1]),(coude_droite[0],coude_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_epaules - centre_hanche
    img = cv2.line(img_cv2, (centre_hanches[0],centre_hanches[1]),(centre_epaules[0],centre_epaules[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_hanche - hanche_gauche
    img = cv2.line(img_cv2, (centre_hanches[0],centre_hanches[1]),(hanche_gauche[0],hanche_gauche[1]),color=(0, 0, 255), thickness=2)

    # Ligne centre_hanche - hanche_gauche
    img = cv2.line(img_cv2, (centre_hanches[0],centre_hanches[1]),(hanche_droite[0],hanche_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne hanche_gauche - genou_gauche
    img = cv2.line(img_cv2, (genou_gauche[0],genou_gauche[1]),(hanche_gauche[0],hanche_gauche[1]),color=(0, 0, 255), thickness=2)

    # Ligne hanche_droite - genou_droite
    img = cv2.line(img_cv2, (genou_droite[0],genou_droite[1]),(hanche_droite[0],hanche_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne genou_droite - cheville_droite
    img = cv2.line(img_cv2, (genou_droite[0],genou_droite[1]),(cheville_droite[0],cheville_droite[1]),color=(0, 0, 255), thickness=2)

    # Ligne genou_gauche - cheville_gauche
    img = cv2.line(img_cv2, (genou_gauche[0],genou_gauche[1]),(cheville_gauche[0],cheville_gauche[1]),color=(0, 0, 255), thickness=2)

    return img

# %%
plt.figure(figsize=(10, 10))

for i in range(8):
    ax = plt.subplot(4, 4, i + 1)
    index = np.random.randint(0,len(dataset_entrainement))
    image = keras.utils.array_to_img(images_entrainement[index][0])
    image = np.array(image)
    draw_image = draw_lines(image, predictions_entrainement[index])
    plt.imshow(draw_image.astype("uint8"))
    plt.title(class_names[np.argmax(labels_entrainement[index], axis=None, out=None)])
    plt.axis("off")

# %% [markdown]
# # Création du modèle

# %% [markdown]
# Le modèle que nous allons utiliser va prendre en entrée les coordonnées des positions et proposer une classification en fonction de ces données.

# %% [markdown]
# Le format des données est le suivant:
# - predictions_entrainement[i] : (17,3)<br>
# - labels_entrainement[i] : (1,2)<br>
#         CORRECT : [1,0];
#         NON_CORRECT : [0,1]

# %%
# Fonction permettant de calculer le centre des hanches de la personne

# entrée : coordonneesXY (BS, 17,3)
# sortie : coordonnées du centre de la hanche [Y, X]
def Calcul_Centre_Hanches(coordonnees):
    hanche_gauche = tf.gather(coordonnees, 11, axis=1)
    hanche_droite = tf.gather(coordonnees, 12, axis=1)
    centre_hanches = 0.5*hanche_gauche + 0.5*hanche_droite
    return centre_hanches  # tenseur (BS,2) : [[Y,X]]

# %%
# Fonction permettant de calculer le centre des épaules de la personne

# entrée : coordonneesXY (BS, 17,3)
# sortie : coordonnées du centre des épaules [Y, X]
def Calcul_Centre_Epaules(coordonnees):
    epaule_gauche = tf.gather(coordonnees, 5, axis=1)
    epaule_droite = tf.gather(coordonnees, 6, axis=1)
    centre_epaules = 0.5*epaule_gauche + 0.5*epaule_droite
    return centre_epaules  # tenseur (BS, 2) : [[Y,X]]

# %%
# Fonction permettant de calculer la taille des coordonnées
# (l'étendue des coordonnées)

# entrée : Coordonnées (BS, 17,2)
# sortie : Maximum en entre :  taille du torse * coefficient_multiplicateur
#                           et distance maximale entre le centre et n'importe quelle coordonnées d'un point de la personne            
def Calcul_Taille_Coordonnees(coordonnees, facteur_multiplicateur_torse=2.5):
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                    # (BS,2) : [[Y,X]]
    
    # Récupère le centre des épaules
    centre_epaules = Calcul_Centre_Epaules(coordonnees)                    # (BS,2) : [[Y,X]]

    # Taille du torse
    taille_torse = tf.linalg.norm(tf.expand_dims(centre_epaules-centre_hanches,1), axis=2)   # (BS,1)
   
    
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                    # (BS,2) : [[Y,X]]
    
    # Création du tenseur pour décaler l'ensemble des coordonnées d'origines
    centre_hanches = tf.expand_dims(centre_hanches, axis=1)                                     # tenseur (BS, 1,2)
    centre_hanches = tf.broadcast_to(centre_hanches, [tf.size(coordonnees) // (17*2), 17, 2])   # tenseur (BS, 17,2)
    
    # Calcul des distances des différents points depuis le centre des hanches
    distances = coordonnees-centre_hanches                 # (BS, 17, 2)
    distances = tf.linalg.norm(distances, axis=2)          # (BS,17)
    
    # Récupère la distance maximale entre le centre des hanches et les points
    max_dist = tf.math.reduce_max(tf.expand_dims(distances,1), axis=2)            # (BS,1)

    # Retourne le maximum entre la distance maximale hanche <=> points
    # et taille du torse*facteur_multiplicatif
    return tf.math.maximum(taille_torse*facteur_multiplicateur_torse, max_dist)

# %%
# Fonction permettant de calculer la taille des coordonnées
# (l'étendue des coordonnées)

# entrée : Coordonnées (BS, 17,2)
# sortie : Maximum en entre :  taille du torse * coefficient_multiplicateur
#                           et distance maximale entre le centre et n'importe quelle coordonnées d'un point de la personne            
def Calcul_Taille_Coordonnees2(coordonnees, facteur_multiplicateur_torse=2.5):
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                    # (BS,2) : [[Y,X]]
    
    # Récupère le centre des épaules
    centre_epaules = Calcul_Centre_Epaules(coordonnees)                    # (BS,2) : [[Y,X]]

    # Taille du torse
    taille_torse = tf.linalg.norm(centre_epaules-centre_hanches) 
   
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                    # (BS,2) : [[Y,X]]
    
    # Création du tenseur pour décaler l'ensemble des coordonnées d'origines
    centre_hanches = tf.expand_dims(centre_hanches, axis=1)                                     # tenseur (BS, 1,2)
    centre_hanches = tf.broadcast_to(centre_hanches, [tf.size(coordonnees) // (17*2), 17, 2])   # tenseur (BS, 17,2)
    
    # Calcul des distances des différents points depuis le centre des hanches
    d = tf.gather(coordonnees - centre_hanches, 0, axis=0, name="dist_to_pose_center")
    
    # Récupère la distance maximale entre le centre des hanches et les points
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Retourne le maximum entre la distance maximale hanche <=> points
    # et taille du torse*facteur_multiplicatif
    return tf.maximum(taille_torse * facteur_multiplicateur_torse, max_dist)

# %%
# Normalisation des données de position 
#  - en translatant le centre des hanches de la personne au coordonnées (0,0)
#  - en redimensionnant les coordonnées de sorte que la taille des coordonnées soit égale à 1

# Entrées :   coordonnees : (BS, 17,3)
def Normalisation_Positions(coordonnees):
    # Récupère le centre des hanches
    centre_hanches = Calcul_Centre_Hanches(coordonnees)                          # tenseur (BS,2) : [[Y,X]]
    
    # Création du tenseur pour décaler l'ensemble des coordonnées d'origines
    centre_hanches = tf.expand_dims(centre_hanches, axis=1)                                         # tenseur (BS,1,2)
    centre_hanches = tf.broadcast_to(centre_hanches, [tf.size(coordonnees) // (17*2), 17, 2])       # tenseur (BS,17,2)
    
    # Soustraction des coordonnées
    nouvelles_coordonnees = coordonnees - centre_hanches                  # (BS, 17,2)
    
    # Redimensionnement des coordonnées
    taille = Calcul_Taille_Coordonnees2(nouvelles_coordonnees)             # (BS)
    nouvelles_coordonnees = nouvelles_coordonnees / taille                # (BS,17,2)
    
    return nouvelles_coordonnees

# %%
# Traitement des entrées
#  - Translate le centre des hanches de la personne aux coordonnées (0,0)
#  - Normalise la position de sorte que sa taille soit égale à 1
#  - Applatissement du tenseur

# tenseur d'entrée : (BS,17,3)

def traitement_entrees(coordonnees_et_scores):
    # Normalisation des positions
    coordonnees = Normalisation_Positions(coordonnees_et_scores[:,:,:2])   

    # Applatissement du tenseur
    return keras.layers.Flatten()(coordonnees)               # (BS,17*2)

# %%
# Définition du modèle
inputs = tf.keras.Input(shape=(17,3))

embedding = traitement_entrees(inputs)

layer = keras.layers.Dense(128, activation=tf.nn.relu6)(embedding)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(2, activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 17, 3)]      0
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 17, 2)        0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather (TFOpLambda (None, 2)            0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_1 (TFOpLamb (None, 2)            0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 2)            0           tf.compat.v1.gather[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 2)            0           tf.math.multiply[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size (TFOpLambda)  ()                   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1, 2)         0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.floor_div (TFOpLam ()                   0           tf.compat.v1.size[0][0]
# __________________________________________________________________________________________________
# tf.broadcast_to (TFOpLambda)    (None, 17, 2)        0           tf.expand_dims[0][0]
#                                                                  tf.compat.v1.floor_div[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 17, 2)        0           tf.__operators__.getitem[0][0]
#                                                                  tf.broadcast_to[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_6 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_7 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 2)            0           tf.math.multiply_6[0][0]
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size_1 (TFOpLambda ()                   0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_4 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_5 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_2 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_3 (TFOpLamb (None, 2)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 1, 2)         0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.floor_div_1 (TFOpL ()                   0           tf.compat.v1.size_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 2)            0           tf.compat.v1.gather_3[0][0]
# __________________________________________________________________________________________________
# tf.broadcast_to_1 (TFOpLambda)  (None, 17, 2)        0           tf.expand_dims_1[0][0]
#                                                                  tf.compat.v1.floor_div_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 2)            0           tf.math.multiply_4[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 2)            0           tf.math.multiply_2[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 17, 2)        0           tf.math.subtract[0][0]
#                                                                  tf.broadcast_to_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 2)            0           tf.__operators__.add_2[0][0]
#                                                                  tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_8 (TFOpLamb (17, 2)              0           tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.norm (TFOpLambda)  ()                   0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.norm_1 (TFOpLambda (2,)                 0           tf.compat.v1.gather_8[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) ()                   0           tf.compat.v1.norm[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max (TFOpLambda) ()                   0           tf.compat.v1.norm_1[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum (TFOpLambda)    ()                   0           tf.math.multiply_8[0][0]
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    (None, 17, 2)        0           tf.math.subtract[0][0]
#                                                                  tf.math.maximum[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 34)           0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          4480        flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            130         dropout_1[0][0]
# ==================================================================================================
# Total params: 12,866
# Trainable params: 12,866
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Entrainement du modèle

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Nombre de périodes d'entrainement
periodes = 300

# Définition de la fonction d'enregistrement automatique du meilleur modèle
model_save = ModelCheckpoint('meilleur_modele.hdf5', save_best_only=True, monitor='val_loss', mode='max')

# Définition de l'ooptimiseur
adam = keras.optimizers.Adam(learning_rate=1e-3)

# Entrainement du modèle : from_logits=True car on utilise un Softmax en sortie de notre modèle
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

historique = model.fit(x=tf.convert_to_tensor(predictions_entrainement), \
                       y=tf.squeeze(tf.convert_to_tensor(labels_entrainement),1), \
                       validation_data=(tf.convert_to_tensor(predictions_validation),tf.squeeze(tf.convert_to_tensor(labels_validation),1)), \
                       verbose=1,epochs=periodes, callbacks=[model_save])
# Out:
# Epoch 1/300
# 2/2 [==============================] - 11s 2s/step - loss: 0.7205 - accuracy: 0.3878 - val_loss: 0.6934 - val_accuracy: 0.4167
# Epoch 2/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.6992 - accuracy: 0.4286 - val_loss: 0.6723 - val_accuracy: 0.8333
# Epoch 3/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6868 - accuracy: 0.5306 - val_loss: 0.6557 - val_accuracy: 0.8333
# Epoch 4/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6819 - accuracy: 0.5714 - val_loss: 0.6410 - val_accuracy: 0.8333
# Epoch 5/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6805 - accuracy: 0.5918 - val_loss: 0.6266 - val_accuracy: 0.8333
# Epoch 6/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6566 - accuracy: 0.6735 - val_loss: 0.6125 - val_accuracy: 0.8333
# Epoch 7/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6638 - accuracy: 0.6531 - val_loss: 0.5979 - val_accuracy: 0.8333
# Epoch 8/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.6619 - accuracy: 0.6531 - val_loss: 0.5847 - val_accuracy: 0.8333
# Epoch 9/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6637 - accuracy: 0.6531 - val_loss: 0.5724 - val_accuracy: 0.8333
# Epoch 10/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6606 - accuracy: 0.6531 - val_loss: 0.5616 - val_accuracy: 0.8333
# Epoch 11/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.6628 - accuracy: 0.6531 - val_loss: 0.5527 - val_accuracy: 0.8333
# Epoch 12/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6544 - accuracy: 0.6531 - val_loss: 0.5448 - val_accuracy: 0.8333
# Epoch 13/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6380 - accuracy: 0.6531 - val_loss: 0.5365 - val_accuracy: 0.8333
# Epoch 14/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6413 - accuracy: 0.6531 - val_loss: 0.5291 - val_accuracy: 0.8333
# Epoch 15/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6524 - accuracy: 0.6531 - val_loss: 0.5221 - val_accuracy: 0.8333
# Epoch 16/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.6203 - accuracy: 0.6531 - val_loss: 0.5140 - val_accuracy: 0.8333
# Epoch 17/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.6337 - accuracy: 0.6531 - val_loss: 0.5068 - val_accuracy: 0.8333
# Epoch 18/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.6251 - accuracy: 0.6531 - val_loss: 0.4997 - val_accuracy: 0.8333
# Epoch 19/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6513 - accuracy: 0.6531 - val_loss: 0.4939 - val_accuracy: 0.8333
# Epoch 20/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.6290 - accuracy: 0.6531 - val_loss: 0.4888 - val_accuracy: 0.8333
# Epoch 21/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6361 - accuracy: 0.6531 - val_loss: 0.4841 - val_accuracy: 0.8333
# Epoch 22/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6462 - accuracy: 0.6531 - val_loss: 0.4812 - val_accuracy: 0.8333
# Epoch 23/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.6351 - accuracy: 0.6531 - val_loss: 0.4795 - val_accuracy: 0.8333
# Epoch 24/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6230 - accuracy: 0.6531 - val_loss: 0.4791 - val_accuracy: 0.8333
# Epoch 25/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.6148 - accuracy: 0.6531 - val_loss: 0.4786 - val_accuracy: 0.8333
# Epoch 26/300
# 2/2 [==============================] - 0s 97ms/step - loss: 0.6227 - accuracy: 0.6531 - val_loss: 0.4778 - val_accuracy: 0.8333
# Epoch 27/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.6232 - accuracy: 0.6531 - val_loss: 0.4754 - val_accuracy: 0.8333
# Epoch 28/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.6182 - accuracy: 0.6531 - val_loss: 0.4732 - val_accuracy: 0.8333
# Epoch 29/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6299 - accuracy: 0.6531 - val_loss: 0.4700 - val_accuracy: 0.8333
# Epoch 30/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6205 - accuracy: 0.6531 - val_loss: 0.4681 - val_accuracy: 0.8333
# Epoch 31/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6012 - accuracy: 0.6531 - val_loss: 0.4657 - val_accuracy: 0.8333
# Epoch 32/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5959 - accuracy: 0.6531 - val_loss: 0.4622 - val_accuracy: 0.8333
# Epoch 33/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6167 - accuracy: 0.6531 - val_loss: 0.4585 - val_accuracy: 0.8333
# Epoch 34/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6055 - accuracy: 0.6531 - val_loss: 0.4545 - val_accuracy: 0.8333
# Epoch 35/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5946 - accuracy: 0.6531 - val_loss: 0.4512 - val_accuracy: 0.8333
# Epoch 36/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5928 - accuracy: 0.6531 - val_loss: 0.4475 - val_accuracy: 0.8333
# Epoch 37/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6081 - accuracy: 0.6531 - val_loss: 0.4441 - val_accuracy: 0.8333
# Epoch 38/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6284 - accuracy: 0.6531 - val_loss: 0.4417 - val_accuracy: 0.8333
# Epoch 39/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6034 - accuracy: 0.6531 - val_loss: 0.4396 - val_accuracy: 0.8333
# Epoch 40/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6215 - accuracy: 0.6531 - val_loss: 0.4387 - val_accuracy: 0.8333
# Epoch 41/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.5822 - accuracy: 0.6531 - val_loss: 0.4389 - val_accuracy: 0.8333
# Epoch 42/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6029 - accuracy: 0.6531 - val_loss: 0.4384 - val_accuracy: 0.8333
# Epoch 43/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5835 - accuracy: 0.6531 - val_loss: 0.4395 - val_accuracy: 0.8333
# Epoch 44/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5864 - accuracy: 0.6531 - val_loss: 0.4401 - val_accuracy: 0.8333
# Epoch 45/300
# 2/2 [==============================] - 0s 97ms/step - loss: 0.6017 - accuracy: 0.6531 - val_loss: 0.4400 - val_accuracy: 0.8333
# Epoch 46/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5760 - accuracy: 0.6531 - val_loss: 0.4410 - val_accuracy: 0.8333
# Epoch 47/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5773 - accuracy: 0.6531 - val_loss: 0.4393 - val_accuracy: 0.8333
# Epoch 48/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5802 - accuracy: 0.6531 - val_loss: 0.4358 - val_accuracy: 0.8333
# Epoch 49/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5625 - accuracy: 0.6531 - val_loss: 0.4310 - val_accuracy: 0.8333
# Epoch 50/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.5717 - accuracy: 0.6531 - val_loss: 0.4244 - val_accuracy: 0.8333
# Epoch 51/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5825 - accuracy: 0.6531 - val_loss: 0.4175 - val_accuracy: 0.8333
# Epoch 52/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5857 - accuracy: 0.6531 - val_loss: 0.4110 - val_accuracy: 0.8333
# Epoch 53/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5992 - accuracy: 0.6531 - val_loss: 0.4059 - val_accuracy: 0.8333
# Epoch 54/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5770 - accuracy: 0.6531 - val_loss: 0.4030 - val_accuracy: 0.8333
# Epoch 55/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5476 - accuracy: 0.6531 - val_loss: 0.4005 - val_accuracy: 0.8333
# Epoch 56/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5515 - accuracy: 0.6531 - val_loss: 0.3939 - val_accuracy: 0.8333
# Epoch 57/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5641 - accuracy: 0.6531 - val_loss: 0.3882 - val_accuracy: 0.8333
# Epoch 58/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5260 - accuracy: 0.7143 - val_loss: 0.3808 - val_accuracy: 0.8333
# Epoch 59/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5422 - accuracy: 0.6939 - val_loss: 0.3724 - val_accuracy: 0.8333
# Epoch 60/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5299 - accuracy: 0.6531 - val_loss: 0.3652 - val_accuracy: 0.8333
# Epoch 61/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5121 - accuracy: 0.6531 - val_loss: 0.3609 - val_accuracy: 0.8333
# Epoch 62/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5453 - accuracy: 0.6531 - val_loss: 0.3561 - val_accuracy: 0.8333
# Epoch 63/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5257 - accuracy: 0.6531 - val_loss: 0.3543 - val_accuracy: 0.8333
# Epoch 64/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5330 - accuracy: 0.6939 - val_loss: 0.3513 - val_accuracy: 0.8333
# Epoch 65/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5166 - accuracy: 0.6939 - val_loss: 0.3518 - val_accuracy: 0.8333
# Epoch 66/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4722 - accuracy: 0.7755 - val_loss: 0.3495 - val_accuracy: 0.8333
# Epoch 67/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5085 - accuracy: 0.7347 - val_loss: 0.3427 - val_accuracy: 0.8333
# Epoch 68/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5006 - accuracy: 0.7959 - val_loss: 0.3347 - val_accuracy: 0.8333
# Epoch 69/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5173 - accuracy: 0.7143 - val_loss: 0.3280 - val_accuracy: 0.8333
# Epoch 70/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4684 - accuracy: 0.7959 - val_loss: 0.3234 - val_accuracy: 0.9167
# Epoch 71/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.4548 - accuracy: 0.7959 - val_loss: 0.3157 - val_accuracy: 0.9167
# Epoch 72/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4801 - accuracy: 0.7551 - val_loss: 0.3049 - val_accuracy: 0.9167
# Epoch 73/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4696 - accuracy: 0.8163 - val_loss: 0.2952 - val_accuracy: 0.9167
# Epoch 74/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4504 - accuracy: 0.7551 - val_loss: 0.2871 - val_accuracy: 0.9167
# Epoch 75/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4530 - accuracy: 0.7551 - val_loss: 0.2796 - val_accuracy: 0.9167
# Epoch 76/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.4587 - accuracy: 0.7755 - val_loss: 0.2715 - val_accuracy: 0.9167
# Epoch 77/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4402 - accuracy: 0.7959 - val_loss: 0.2659 - val_accuracy: 0.9167
# Epoch 78/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4155 - accuracy: 0.8571 - val_loss: 0.2614 - val_accuracy: 0.9167
# Epoch 79/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.4484 - accuracy: 0.7755 - val_loss: 0.2582 - val_accuracy: 0.9167
# Epoch 80/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.4286 - accuracy: 0.7959 - val_loss: 0.2556 - val_accuracy: 0.9167
# Epoch 81/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4159 - accuracy: 0.7959 - val_loss: 0.2567 - val_accuracy: 0.9167
# Epoch 82/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4287 - accuracy: 0.8367 - val_loss: 0.2602 - val_accuracy: 1.0000
# Epoch 83/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4115 - accuracy: 0.8367 - val_loss: 0.2610 - val_accuracy: 1.0000
# Epoch 84/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4226 - accuracy: 0.9388 - val_loss: 0.2558 - val_accuracy: 1.0000
# Epoch 85/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4016 - accuracy: 0.8776 - val_loss: 0.2469 - val_accuracy: 1.0000
# Epoch 86/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.3603 - accuracy: 0.9388 - val_loss: 0.2365 - val_accuracy: 1.0000
# Epoch 87/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4091 - accuracy: 0.8571 - val_loss: 0.2276 - val_accuracy: 1.0000
# Epoch 88/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.3777 - accuracy: 0.9184 - val_loss: 0.2234 - val_accuracy: 1.0000
# Epoch 89/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3862 - accuracy: 0.8163 - val_loss: 0.2219 - val_accuracy: 1.0000
# Epoch 90/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3547 - accuracy: 0.8776 - val_loss: 0.2234 - val_accuracy: 1.0000
# Epoch 91/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.3723 - accuracy: 0.8776 - val_loss: 0.2206 - val_accuracy: 1.0000
# Epoch 92/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.3508 - accuracy: 0.9388 - val_loss: 0.2128 - val_accuracy: 1.0000
# Epoch 93/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.3575 - accuracy: 0.9388 - val_loss: 0.2040 - val_accuracy: 1.0000
# Epoch 94/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.3417 - accuracy: 0.9592 - val_loss: 0.1944 - val_accuracy: 1.0000
# Epoch 95/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.3214 - accuracy: 0.9388 - val_loss: 0.1867 - val_accuracy: 1.0000
# Epoch 96/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.3132 - accuracy: 0.9184 - val_loss: 0.1817 - val_accuracy: 1.0000
# Epoch 97/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.3365 - accuracy: 0.8980 - val_loss: 0.1795 - val_accuracy: 1.0000
# Epoch 98/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.3304 - accuracy: 0.9184 - val_loss: 0.1810 - val_accuracy: 1.0000
# Epoch 99/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2971 - accuracy: 0.9592 - val_loss: 0.1850 - val_accuracy: 1.0000
# Epoch 100/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.3341 - accuracy: 0.8776 - val_loss: 0.1841 - val_accuracy: 1.0000
# Epoch 101/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.3325 - accuracy: 0.8776 - val_loss: 0.1782 - val_accuracy: 1.0000
# Epoch 102/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3177 - accuracy: 0.8571 - val_loss: 0.1713 - val_accuracy: 1.0000
# Epoch 103/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2908 - accuracy: 0.9388 - val_loss: 0.1647 - val_accuracy: 1.0000
# Epoch 104/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.2764 - accuracy: 0.9592 - val_loss: 0.1555 - val_accuracy: 1.0000
# Epoch 105/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2596 - accuracy: 0.9184 - val_loss: 0.1521 - val_accuracy: 1.0000
# Epoch 106/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2870 - accuracy: 0.8980 - val_loss: 0.1523 - val_accuracy: 1.0000
# Epoch 107/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.2743 - accuracy: 0.9388 - val_loss: 0.1534 - val_accuracy: 1.0000
# Epoch 108/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.3041 - accuracy: 0.8571 - val_loss: 0.1536 - val_accuracy: 1.0000
# Epoch 109/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2430 - accuracy: 0.9592 - val_loss: 0.1476 - val_accuracy: 1.0000
# Epoch 110/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2839 - accuracy: 0.9184 - val_loss: 0.1426 - val_accuracy: 1.0000
# Epoch 111/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2877 - accuracy: 0.9184 - val_loss: 0.1421 - val_accuracy: 1.0000
# Epoch 112/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2573 - accuracy: 0.9592 - val_loss: 0.1462 - val_accuracy: 1.0000
# Epoch 113/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2330 - accuracy: 0.9592 - val_loss: 0.1450 - val_accuracy: 1.0000
# Epoch 114/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2445 - accuracy: 0.9388 - val_loss: 0.1364 - val_accuracy: 1.0000
# Epoch 115/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2781 - accuracy: 0.9184 - val_loss: 0.1281 - val_accuracy: 1.0000
# Epoch 116/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.2783 - accuracy: 0.8980 - val_loss: 0.1254 - val_accuracy: 1.0000
# Epoch 117/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.2831 - accuracy: 0.9184 - val_loss: 0.1259 - val_accuracy: 1.0000
# Epoch 118/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2529 - accuracy: 0.8980 - val_loss: 0.1271 - val_accuracy: 1.0000
# Epoch 119/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.2291 - accuracy: 0.9592 - val_loss: 0.1268 - val_accuracy: 1.0000
# Epoch 120/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.2669 - accuracy: 0.9388 - val_loss: 0.1228 - val_accuracy: 1.0000
# Epoch 121/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.2437 - accuracy: 0.9388 - val_loss: 0.1208 - val_accuracy: 1.0000
# Epoch 122/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2554 - accuracy: 0.8776 - val_loss: 0.1215 - val_accuracy: 1.0000
# Epoch 123/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.2217 - accuracy: 0.9388 - val_loss: 0.1227 - val_accuracy: 1.0000
# Epoch 124/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.2474 - accuracy: 0.8776 - val_loss: 0.1233 - val_accuracy: 1.0000
# Epoch 125/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.2439 - accuracy: 0.9184 - val_loss: 0.1264 - val_accuracy: 1.0000
# Epoch 126/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2259 - accuracy: 0.9388 - val_loss: 0.1267 - val_accuracy: 1.0000
# Epoch 127/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2465 - accuracy: 0.8776 - val_loss: 0.1211 - val_accuracy: 1.0000
# Epoch 128/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2314 - accuracy: 0.9388 - val_loss: 0.1151 - val_accuracy: 1.0000
# Epoch 129/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1900 - accuracy: 0.9796 - val_loss: 0.1144 - val_accuracy: 1.0000
# Epoch 130/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2251 - accuracy: 0.9388 - val_loss: 0.1121 - val_accuracy: 1.0000
# Epoch 131/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.2250 - accuracy: 0.9184 - val_loss: 0.1098 - val_accuracy: 1.0000
# Epoch 132/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2380 - accuracy: 0.8776 - val_loss: 0.1157 - val_accuracy: 1.0000
# Epoch 133/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.2188 - accuracy: 0.9592 - val_loss: 0.1251 - val_accuracy: 1.0000
# Epoch 134/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2101 - accuracy: 0.9592 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 135/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2200 - accuracy: 0.9388 - val_loss: 0.1198 - val_accuracy: 1.0000
# Epoch 136/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2271 - accuracy: 0.9592 - val_loss: 0.1138 - val_accuracy: 1.0000
# Epoch 137/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1885 - accuracy: 0.9388 - val_loss: 0.1056 - val_accuracy: 1.0000
# Epoch 138/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1951 - accuracy: 0.9592 - val_loss: 0.1016 - val_accuracy: 1.0000
# Epoch 139/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2340 - accuracy: 0.9388 - val_loss: 0.0997 - val_accuracy: 1.0000
# Epoch 140/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1910 - accuracy: 0.9388 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 141/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1683 - accuracy: 0.9796 - val_loss: 0.1018 - val_accuracy: 1.0000
# Epoch 142/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1719 - accuracy: 0.9592 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 143/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1826 - accuracy: 0.9388 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 144/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1968 - accuracy: 0.9388 - val_loss: 0.1013 - val_accuracy: 1.0000
# Epoch 145/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1471 - accuracy: 0.9796 - val_loss: 0.1060 - val_accuracy: 1.0000
# Epoch 146/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1919 - accuracy: 0.9388 - val_loss: 0.1051 - val_accuracy: 1.0000
# Epoch 147/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1883 - accuracy: 0.9388 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 148/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2120 - accuracy: 0.9388 - val_loss: 0.0942 - val_accuracy: 1.0000
# Epoch 149/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1823 - accuracy: 0.9592 - val_loss: 0.0905 - val_accuracy: 1.0000
# Epoch 150/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1966 - accuracy: 0.9184 - val_loss: 0.0905 - val_accuracy: 1.0000
# Epoch 151/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.2074 - accuracy: 0.8980 - val_loss: 0.0904 - val_accuracy: 1.0000
# Epoch 152/300
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1398 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 1.0000
# Epoch 153/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1680 - accuracy: 0.9796 - val_loss: 0.1062 - val_accuracy: 1.0000
# Epoch 154/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1650 - accuracy: 0.9592 - val_loss: 0.1082 - val_accuracy: 0.9167
# Epoch 155/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1444 - accuracy: 0.9592 - val_loss: 0.0984 - val_accuracy: 1.0000
# Epoch 156/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1409 - accuracy: 0.9796 - val_loss: 0.0837 - val_accuracy: 1.0000
# Epoch 157/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1410 - accuracy: 0.9592 - val_loss: 0.0767 - val_accuracy: 1.0000
# Epoch 158/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1350 - accuracy: 0.9796 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 159/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1675 - accuracy: 0.9592 - val_loss: 0.0786 - val_accuracy: 1.0000
# Epoch 160/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1675 - accuracy: 0.9592 - val_loss: 0.0879 - val_accuracy: 1.0000
# Epoch 161/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1614 - accuracy: 0.9184 - val_loss: 0.1022 - val_accuracy: 0.9167
# Epoch 162/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1475 - accuracy: 0.9388 - val_loss: 0.1352 - val_accuracy: 0.9167
# Epoch 163/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1433 - accuracy: 0.9592 - val_loss: 0.1610 - val_accuracy: 0.9167
# Epoch 164/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1883 - accuracy: 0.9184 - val_loss: 0.1600 - val_accuracy: 0.9167
# Epoch 165/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1493 - accuracy: 0.9592 - val_loss: 0.1451 - val_accuracy: 0.9167
# Epoch 166/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1717 - accuracy: 0.9388 - val_loss: 0.1199 - val_accuracy: 0.9167
# Epoch 167/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1649 - accuracy: 0.9184 - val_loss: 0.0939 - val_accuracy: 1.0000
# Epoch 168/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1326 - accuracy: 0.9592 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 169/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1281 - accuracy: 0.9592 - val_loss: 0.0666 - val_accuracy: 1.0000
# Epoch 170/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1027 - accuracy: 0.9796 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 171/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1619 - accuracy: 0.9388 - val_loss: 0.0634 - val_accuracy: 1.0000
# Epoch 172/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1489 - accuracy: 0.9796 - val_loss: 0.0693 - val_accuracy: 1.0000
# Epoch 173/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1555 - accuracy: 0.9592 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 174/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.1759 - accuracy: 0.9592 - val_loss: 0.1032 - val_accuracy: 0.9167
# Epoch 175/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1611 - accuracy: 0.9592 - val_loss: 0.1168 - val_accuracy: 0.9167
# Epoch 176/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1474 - accuracy: 0.9592 - val_loss: 0.1143 - val_accuracy: 0.9167
# Epoch 177/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1288 - accuracy: 0.9796 - val_loss: 0.1049 - val_accuracy: 0.9167
# Epoch 178/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1664 - accuracy: 0.9388 - val_loss: 0.0914 - val_accuracy: 0.9167
# Epoch 179/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1167 - accuracy: 0.9592 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 180/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1621 - accuracy: 0.9388 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 181/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1562 - accuracy: 0.9388 - val_loss: 0.0612 - val_accuracy: 1.0000
# Epoch 182/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1854 - accuracy: 0.9388 - val_loss: 0.0643 - val_accuracy: 1.0000
# Epoch 183/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1314 - accuracy: 0.9592 - val_loss: 0.0749 - val_accuracy: 1.0000
# Epoch 184/300
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1204 - accuracy: 0.9796 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 185/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1246 - accuracy: 0.9388 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 186/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1085 - accuracy: 0.9796 - val_loss: 0.0793 - val_accuracy: 1.0000
# Epoch 187/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1383 - accuracy: 0.9796 - val_loss: 0.0706 - val_accuracy: 1.0000
# Epoch 188/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0868 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 189/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1084 - accuracy: 0.9592 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 190/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1288 - accuracy: 0.9592 - val_loss: 0.0555 - val_accuracy: 1.0000
# Epoch 191/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1605 - accuracy: 0.9592 - val_loss: 0.0574 - val_accuracy: 1.0000
# Epoch 192/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1436 - accuracy: 0.9592 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 193/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1133 - accuracy: 0.9592 - val_loss: 0.0838 - val_accuracy: 0.9167
# Epoch 194/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1187 - accuracy: 0.9592 - val_loss: 0.0936 - val_accuracy: 0.9167
# Epoch 195/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1065 - accuracy: 0.9796 - val_loss: 0.0982 - val_accuracy: 0.9167
# Epoch 196/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1564 - accuracy: 0.9388 - val_loss: 0.0934 - val_accuracy: 0.9167
# Epoch 197/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1662 - accuracy: 0.9592 - val_loss: 0.0803 - val_accuracy: 1.0000
# Epoch 198/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1058 - accuracy: 0.9592 - val_loss: 0.0708 - val_accuracy: 1.0000
# Epoch 199/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1249 - accuracy: 0.9796 - val_loss: 0.0666 - val_accuracy: 1.0000
# Epoch 200/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0922 - accuracy: 0.9796 - val_loss: 0.0646 - val_accuracy: 1.0000
# Epoch 201/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1792 - accuracy: 0.8980 - val_loss: 0.0646 - val_accuracy: 1.0000
# Epoch 202/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0993 - accuracy: 0.9592 - val_loss: 0.0748 - val_accuracy: 1.0000
# Epoch 203/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1089 - accuracy: 0.9796 - val_loss: 0.0893 - val_accuracy: 0.9167
# Epoch 204/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1309 - accuracy: 0.9184 - val_loss: 0.0969 - val_accuracy: 0.9167
# Epoch 205/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1121 - accuracy: 0.9796 - val_loss: 0.0845 - val_accuracy: 0.9167
# Epoch 206/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1121 - accuracy: 0.9796 - val_loss: 0.0754 - val_accuracy: 1.0000
# Epoch 207/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1347 - accuracy: 0.9592 - val_loss: 0.0727 - val_accuracy: 1.0000
# Epoch 208/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1160 - accuracy: 0.9592 - val_loss: 0.0720 - val_accuracy: 1.0000
# Epoch 209/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0929 - accuracy: 1.0000 - val_loss: 0.0694 - val_accuracy: 1.0000
# Epoch 210/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1683 - accuracy: 0.9184 - val_loss: 0.0673 - val_accuracy: 1.0000
# Epoch 211/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1486 - accuracy: 0.9388 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 212/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1310 - accuracy: 0.9592 - val_loss: 0.0845 - val_accuracy: 0.9167
# Epoch 213/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1489 - accuracy: 0.9388 - val_loss: 0.0947 - val_accuracy: 0.9167
# Epoch 214/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1261 - accuracy: 0.9796 - val_loss: 0.0985 - val_accuracy: 0.9167
# Epoch 215/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1242 - accuracy: 0.9796 - val_loss: 0.0913 - val_accuracy: 0.9167
# Epoch 216/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1364 - accuracy: 0.9388 - val_loss: 0.0822 - val_accuracy: 0.9167
# Epoch 217/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0773 - accuracy: 0.9796 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 218/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1408 - accuracy: 0.9388 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 219/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1059 - accuracy: 0.9592 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 220/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1259 - accuracy: 0.9592 - val_loss: 0.0441 - val_accuracy: 1.0000
# Epoch 221/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1247 - accuracy: 0.9592 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 222/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1036 - accuracy: 0.9796 - val_loss: 0.0428 - val_accuracy: 1.0000
# Epoch 223/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1397 - accuracy: 0.9796 - val_loss: 0.0531 - val_accuracy: 1.0000
# Epoch 224/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1079 - accuracy: 0.9796 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 225/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0753 - accuracy: 0.9796 - val_loss: 0.0799 - val_accuracy: 0.9167
# Epoch 226/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1037 - accuracy: 0.9796 - val_loss: 0.0857 - val_accuracy: 0.9167
# Epoch 227/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0976 - accuracy: 0.9796 - val_loss: 0.0804 - val_accuracy: 0.9167
# Epoch 228/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1343 - accuracy: 0.9592 - val_loss: 0.0706 - val_accuracy: 1.0000
# Epoch 229/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0917 - accuracy: 0.9796 - val_loss: 0.0658 - val_accuracy: 1.0000
# Epoch 230/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1113 - accuracy: 0.9796 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 231/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.1458 - accuracy: 0.9184 - val_loss: 0.0616 - val_accuracy: 1.0000
# Epoch 232/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.1136 - accuracy: 0.9796 - val_loss: 0.0597 - val_accuracy: 1.0000
# Epoch 233/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1519 - accuracy: 0.9388 - val_loss: 0.0616 - val_accuracy: 1.0000
# Epoch 234/300
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1136 - accuracy: 0.9796 - val_loss: 0.0693 - val_accuracy: 1.0000
# Epoch 235/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0986 - accuracy: 0.9592 - val_loss: 0.0708 - val_accuracy: 1.0000
# Epoch 236/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1156 - accuracy: 0.9592 - val_loss: 0.0651 - val_accuracy: 1.0000
# Epoch 237/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0947 - accuracy: 0.9592 - val_loss: 0.0557 - val_accuracy: 1.0000
# Epoch 238/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1258 - accuracy: 0.9388 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 239/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1328 - accuracy: 0.9592 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 240/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1112 - accuracy: 0.9388 - val_loss: 0.0459 - val_accuracy: 1.0000
# Epoch 241/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0760 - accuracy: 0.9796 - val_loss: 0.0444 - val_accuracy: 1.0000
# Epoch 242/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1435 - accuracy: 0.9388 - val_loss: 0.0464 - val_accuracy: 1.0000
# Epoch 243/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0935 - accuracy: 0.9796 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 244/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1144 - accuracy: 0.9592 - val_loss: 0.0611 - val_accuracy: 1.0000
# Epoch 245/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1008 - accuracy: 0.9796 - val_loss: 0.0663 - val_accuracy: 1.0000
# Epoch 246/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0851 - accuracy: 0.9796 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 247/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1027 - accuracy: 0.9388 - val_loss: 0.0552 - val_accuracy: 1.0000
# Epoch 248/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1174 - accuracy: 0.9592 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 249/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1186 - accuracy: 0.9592 - val_loss: 0.0416 - val_accuracy: 1.0000
# Epoch 250/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1031 - accuracy: 0.9796 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 251/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0840 - accuracy: 0.9796 - val_loss: 0.0439 - val_accuracy: 1.0000
# Epoch 252/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0957 - accuracy: 0.9796 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 253/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0807 - accuracy: 1.0000 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 254/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0992 - accuracy: 0.9592 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 255/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 256/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1117 - accuracy: 0.9592 - val_loss: 0.0715 - val_accuracy: 0.9167
# Epoch 257/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1162 - accuracy: 0.9796 - val_loss: 0.0676 - val_accuracy: 1.0000
# Epoch 258/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1408 - accuracy: 0.9388 - val_loss: 0.0570 - val_accuracy: 1.0000
# Epoch 259/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0823 - accuracy: 0.9796 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 260/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0755 - accuracy: 0.9796 - val_loss: 0.0506 - val_accuracy: 1.0000
# Epoch 261/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1083 - accuracy: 0.9796 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 262/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0935 - accuracy: 0.9592 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 263/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 1.0000
# Epoch 264/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1005 - accuracy: 0.9592 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 265/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0931 - accuracy: 0.9796 - val_loss: 0.0556 - val_accuracy: 1.0000
# Epoch 266/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0950 - accuracy: 0.9796 - val_loss: 0.0601 - val_accuracy: 1.0000
# Epoch 267/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0949 - accuracy: 0.9796 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 268/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1114 - accuracy: 0.9592 - val_loss: 0.0720 - val_accuracy: 0.9167
# Epoch 269/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1135 - accuracy: 0.9592 - val_loss: 0.0760 - val_accuracy: 0.9167
# Epoch 270/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1415 - accuracy: 0.9592 - val_loss: 0.0688 - val_accuracy: 0.9167
# Epoch 271/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1711 - accuracy: 0.8980 - val_loss: 0.0525 - val_accuracy: 1.0000
# Epoch 272/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1372 - accuracy: 0.9592 - val_loss: 0.0356 - val_accuracy: 1.0000
# Epoch 273/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0859 - accuracy: 0.9592 - val_loss: 0.0308 - val_accuracy: 1.0000
# Epoch 274/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0975 - accuracy: 0.9796 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 275/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1228 - accuracy: 0.9796 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 276/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1009 - accuracy: 0.9796 - val_loss: 0.0465 - val_accuracy: 1.0000
# Epoch 277/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0775 - accuracy: 0.9796 - val_loss: 0.0639 - val_accuracy: 1.0000
# Epoch 278/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1340 - accuracy: 0.9592 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 279/300
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0589 - accuracy: 0.9796 - val_loss: 0.0599 - val_accuracy: 1.0000
# Epoch 280/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0657 - accuracy: 0.9796 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 281/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0853 - accuracy: 0.9796 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 282/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0724 - accuracy: 0.9796 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 283/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.1167 - accuracy: 0.9592 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 284/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1425 - accuracy: 0.9592 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 285/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1118 - accuracy: 0.9592 - val_loss: 0.0295 - val_accuracy: 1.0000
# Epoch 286/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1013 - accuracy: 0.9388 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 287/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0879 - accuracy: 0.9796 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 288/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1372 - accuracy: 0.9388 - val_loss: 0.0441 - val_accuracy: 1.0000
# Epoch 289/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0813 - accuracy: 0.9796 - val_loss: 0.0414 - val_accuracy: 1.0000
# Epoch 290/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1212 - accuracy: 0.9796 - val_loss: 0.0376 - val_accuracy: 1.0000
# Epoch 291/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0727 - accuracy: 0.9796 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 292/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0794 - accuracy: 0.9592 - val_loss: 0.0405 - val_accuracy: 1.0000
# Epoch 293/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0600 - accuracy: 0.9796 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 294/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0981 - accuracy: 0.9592 - val_loss: 0.0401 - val_accuracy: 1.0000
# Epoch 295/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1305 - accuracy: 0.9592 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 296/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0982 - accuracy: 0.9796 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 297/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.1223 - accuracy: 0.9796 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 298/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0954 - accuracy: 0.9592 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 299/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1156 - accuracy: 0.9592 - val_loss: 0.0631 - val_accuracy: 1.0000
# Epoch 300/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0822 - accuracy: 0.9796 - val_loss: 0.0771 - val_accuracy: 0.9167

# %%
# Affichage de la progression de l'entrainement

plt.plot(historique.history['accuracy'])
plt.plot(historique.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.show()

# %% [markdown]
# # Tests du modèle sur les données de validation

# %% [markdown]
# Les probabilités du label CORRECT sont affichées entre crochets :

# %%
plt.figure(figsize=(10, 10))

for i in range(8):
    ax = plt.subplot(4, 4, i + 1)
    index = np.random.randint(0,len(dataset_validation))
    image = keras.utils.array_to_img(images_validation[index][0])
    image = np.array(image)
    draw_image = draw_lines(image, predictions_validation[index])
    
    pred = model(tf.expand_dims(tf.convert_to_tensor(predictions_validation[index]),0))
    
    plt.imshow(draw_image.astype("uint8"))
    plt.title(class_names[np.argmax(labels_validation[index], axis=None, out=None)]+" [%.1f]" %(pred.numpy()[0][0]))
    plt.axis("off")

# %% [markdown]
# # Sauvegarde du modèle

# %%
# !mkdir "SaveModel"

# %%
tf.saved_model.save(model,"/home/jetson/notebook/Olympiades2024/3. Model_Classification/SaveModel")
# Out:
# INFO:tensorflow:Assets written to: /home/jetson/notebook/Olympiades2024/3. Model_Classification/SaveModel/assets
