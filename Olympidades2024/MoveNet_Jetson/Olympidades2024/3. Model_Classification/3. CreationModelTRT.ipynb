# %%
# !/home/jetson/TensorRT/build/trtexec --fp16 --onnx="modele_classification.onnx" --saveEngine="model_classification.engine"
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8205] # /home/jetson/TensorRT/build/trtexec --fp16 --onnx=modele_classification.onnx --saveEngine=model_classification.engine
# [03/26/2024-12:17:04] [I] === Model Options ===
# [03/26/2024-12:17:04] [I] Format: ONNX
# [03/26/2024-12:17:04] [I] Model: modele_classification.onnx
# [03/26/2024-12:17:04] [I] Output:
# [03/26/2024-12:17:04] [I] === Build Options ===
# [03/26/2024-12:17:04] [I] Max batch: explicit batch
# [03/26/2024-12:17:04] [I] Workspace: 16 MiB
# [03/26/2024-12:17:04] [I] minTiming: 1
# [03/26/2024-12:17:04] [I] avgTiming: 8
# [03/26/2024-12:17:04] [I] Precision: FP32+FP16
# [03/26/2024-12:17:04] [I] Calibration:
# [03/26/2024-12:17:04] [I] Refit: Disabled
# [03/26/2024-12:17:04] [I] Sparsity: Disabled
# [03/26/2024-12:17:04] [I] Safe mode: Disabled
# [03/26/2024-12:17:04] [I] DirectIO mode: Disabled
# [03/26/2024-12:17:04] [I] Restricted mode: Disabled
# [03/26/2024-12:17:04] [I] Save engine: model_classification.engine
# ...
